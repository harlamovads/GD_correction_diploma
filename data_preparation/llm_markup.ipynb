# %%
# !pip install -q together datasets

# %%
# !pip install -q huggingface_hub

# %%
from datasets import load_dataset

ds = load_dataset("Zlovoblachko/REALEC_GEC_dataset")

# %%
from together import Together
from tqdm import tqdm

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['source', 'target', '__index_level_0__'],
#         num_rows: 28465
#     })
#     validation: Dataset({
#         features: ['source', 'target', '__index_level_0__'],
#         num_rows: 3558
#     })
#     test: Dataset({
#         features: ['source', 'target', '__index_level_0__'],
#         num_rows: 3559
#     })
# })

# %%
len(ds['test']['source'])
# Out:
# 3559

# %%
len(ds['validation']['source'])
# Out:
# 3558

# %%
corrections = []

# %%
chunks = [ds['test']['source'][i:i+10] for i in range(0, len(ds['test']['source']), 10)]

# %%
client = Together(api_key=API_KEY)

# %%
corrections_test_1 = []

# %%
from tqdm import tqdm
import json
from pydantic import BaseModel, Field

for chunk_sentences in tqdm(chunks[76:]):
    try:
        sentences_text = '\n'.join(chunk_sentences)
        sentence_count = len(chunk_sentences)
        
        # Define the schema for the output
        class CorrectedSentences(BaseModel):
            corrections: list[str] = Field(
                description="A list of corrected sentences with grammatical, lexical and style errors fixed",
                min_items=sentence_count,
                max_items=sentence_count
            )
        
        prompt = f"Correct grammatical, lexical and style errors in the following {sentence_count} sentences without changing the meaning. Paraphrase the sentences to avoid uncommon and ungrammatical expressions. Do not make more corrections than necessary. Return exactly {sentence_count} corrected sentences in the same order as the original."
        
        # Call the LLM with the JSON schema
        completion = client.chat.completions.create(
            model="meta-llama/Llama-3.3-70B-Instruct-Turbo-Free",
            messages=[
                {
                    "role": "system",
                    "content": "You are an assistant proficient in English that corrects text. Only answer in JSON format. Return exactly the same number of sentences as provided."
                },
                {
                    "role": "user",
                    "content": prompt + "\n\n" + sentences_text
                }
            ],
            response_format={
                "type": "json_object",
                "schema": CorrectedSentences.model_json_schema()
            },
            temperature=0.3,
            seed=42,
            stream=False  # JSON mode isn't compatible with streaming
        )
        
        # Parse the JSON response
        output = json.loads(completion.choices[0].message.content)
        
        # Validate the count of returned sentences
        if len(output["corrections"]) != sentence_count:
            raise ValueError(f"Expected {sentence_count} sentences, but got {len(output['corrections'])}")
            
        corrections_test_1.extend(output["corrections"])
    except Exception as e:
        print(f"Error processing chunk: {e}")
        break
# Out:
#   0%|          | 0/280 [00:00<?, ?it/s]
# 100%|██████████| 280/280 [35:18<00:00,  7.57s/it]

# %%
with open('corrections_test.json', 'a+') as f:
    f.write('\n'.join(corrections_test_1))

# %%
chunks[75]
# Out:
# ['Another noticeable similarity is the numbers of men/women workes are almost the same in the industial field in both countries.',
#  'The chart shows the time spent doing sport and exercise in England in 2012 by men and women of different age.',
#  'At the same way the rate went down in Latin America but only for 1 percent.',
#  'The first chart illustrates number of users in millions and the second one - different reasons to use Facebook for men and women.',
#  'However, this age-category prevailed in attending art courses.',
#  'Industry sector was more popular amongst male and female - 32% male and 11% female.',
#  'Graphs provide us information about changes in population size, birth rate and death rate in the USA from 1750 till 2000.',
#  'There are 2 kind of transportation: by rail and by road.',
#  'The bar chart shows the percentage of overweight girls and boys in the period between 1985 and 2005, and the table below it depicts percentage of boys and girls who did regular physical activity from 1990 to 2005.\nfrom the chart is clear that from 1985 to 1995 the was more overweight girls than boys, while in 1995 became equal in 16 percents.',
#  'In Yakutsk it is normally to have a -40° degrees.']

# %%
output['corrections']
# Out:
# ['Another noticeable similarity is that the number of men and women working in the industrial field is almost the same in both countries.',
#  'The chart shows the time spent on sports and exercise in England in 2012 by men and women of different ages.',
#  'In the same way, the rate decreased in Latin America, but only by 1 percent.',
#  'The first chart illustrates the number of users in millions, and the second one shows different reasons for men and women to use Facebook.',
#  'However, this age category prevailed in terms of attending art courses.',
#  'The industry sector was more popular among males and females, with 32% male and 11% female.',
#  'The graphs provide information about changes in population size, birth rate, and death rate in the USA from 1750 to 2000.',
#  'There are two kinds of transportation: by rail and by road.',
#  'The bar chart shows the percentage of overweight girls and boys between 1985 and 2005, and the table below it depicts the percentage of boys and girls who engaged in regular physical activity from 1990 to 2005.',
#  'It is clear from the chart that from 1985 to 1995, there were more overweight girls than boys, while in 1995, the percentages became equal at 16 percent.',
#  'In Yakutsk, it is normal to have temperatures of -40 degrees.']

# %%
with open('corrections_test.json', 'a+') as f:
    f.write('\n'.join(output['corrections']))

# %%
len(corrections)
# Out:
# 3558

# %%
len(ds['validation']['source'])
# Out:
# 3558

# %%
chunks[1886]
# Out:
# ['The charts shows us goods transportation by rail and by road in Eastern Europe in the year 2008.',
#  'Moreover, boys who have not access to primary school are more than girls around the world.',
#  'The graph which is painted below demonstrate us the differences in the proportions of population of 65 - years and over people for 100 years between 1940 and 2040 in Japan, Sweden and in the USA.',
#  'While the table presents the propotion of them involved in physical activity daily.',
#  'All the other changes shown on a chart are smooth and steady.',
#  'Over the span of 12 years a number of boys and girls in the rets of world decreased from 10, 6 and 12,8 millions to 5,5 and 7,6 millions respectively.',
#  'on the countrary the lowest temputer in Rio de Janeiro is in Julay (about 14 degrees above zero), if we look at graph loketted to Russia, we can notice that in comparing to Brazil the difference between the maximum and minimum temperature is more than 60 degrees.',
#  'That goods constitute just over a half of all commodities transported by road.',
#  'Moreover, adolescents do exercise more often than others age groops (282,1 for males and 114,1 for females respectively)\nFirst of all, in the age groop from 25 to 34 males also do more sport than women (nearly 154 minutes and approximately 93 minutes respectively).',
#  'The older railway systems are assosiated with longer routes.']

# %%
output['corrections']
# Out:
# ['Overall, it can be clearly seen that the mentioned difference decreased in all countries.',
#  'Overall, the gap in the amount of investment in renewable energy between developed and developing countries decreased.',
#  'The majority of students in this course are 18 to 25 years old, accounting for slightly more than half of the applicants, and the age group with the least number of students was 40 years old and above.',
#  'For Indonesia, it can be clearly seen that most men preferred working in services, but for women, there was only a slight difference between the number of employees in the agricultural sector, with 43% of workers, and the services sector, with 49% of workers.',
#  'The first countries are the USA, UK, and Japan, whose numbers started at around 40 in 1980 and decreased to less than 15 in 1995.',
#  'The rest of the world presents a different picture.',
#  'Moreover, it can be said that Japan had less than 5% until 2000.',
#  'The agricultural sector in Indonesia, as the table shows, is mostly occupied by female workers, while male employees prevail in other areas.',
#  'People from the USA also had considerably diverse earnings compared to Japan.',
#  'Another interesting point is that the majority of mid-aged students chose sports and arts courses, while arts and science courses were chosen with almost the same percentage.']

# %%
with open('corrections.json', 'a+') as f:
    f.write('\n'.join(output['corrections']))

# %%
len(corrections_cont_21)
# Out:
# 840

# %%
with open('corrections_validation.json', 'a+') as f:
    f.write('\n'.join(corrections))

# %%
len(ds['train']['source'])
# Out:
# 28465

# %%
with open('sources.json', 'a+') as f:
    f.write('\n'.join(ds['train']['source']))

# %%
with open('corrections_clean.txt', 'a+') as f:
    f.write('\n'.join(corrections_cont))

# %%
corrections_cont[0:10]
# Out:
# ['The graph below shows the volume of goods transported between Eastern European countries in 2008.',
#  'Overall, it can be seen that the younger the people, the more time they spent on sports and exercises.',
#  'Many women use Facebook primarily to share photos and videos with other users or to view funny posts.',
#  'It is noticeable that in both countries, there are more male workers than female workers in the industry sector, while in the other two sectors, the percentage depends on the country.',
#  'The interesting fact is that the 55-64 age group differs significantly from the other groups.',
#  'Additionally, chemicals are transported almost equally by rail and road, although the percentage is relatively high (11-16%).',
#  'In conclusion, it is clear that the number of Facebook users started to decline, and the main audience of the network is women who enjoy using the site to share photos and enjoy memes.',
#  'The first graphic illustrates the goods that were transported by rail.',
#  'Overall, it can be seen that in both modes of transportation, the most popular type of goods is manufactured goods, which together account for approximately one-third of all goods.',
#  'The most dramatic gaps are in the years 2010 and 2011, where developed countries spent approximately $70 billion more than the other category.']

# %%
len(chunks)
# Out:
# 2847

# %%
for chunk_sentences in tqdm(chunks):
    with open('sources_clean.json', 'a+') as f:
        f.write('\n'.join(chunk_sentences))
# Out:
# 100%|██████████| 2847/2847 [00:00<00:00, 77484.30it/s]

# %%
with open('corrections.json', 'r') as f:
    corrections_fw = f.readlines()
with open('sources.json', 'r') as f:
    sources_fw = f.readlines()

# %%
assert len(corrections_fw) == len(sources_fw)

# %%
from huggingface_hub import login
login(TOKEN)

# %%
ds['validation']['source']
# Out:
# ['Sports and Health cources can be named as the "oldest" because their visitors mostly 26-40 years old- 62% and older than 40 years old - 23% from total amount of people (630 students).',
#  'To sum up, young generation prefer communication via the Internet more often than elderly people.',
#  'Also, the percentage of 40 years old and above people on different courses is less then half.',
#  'It can be clearly seen from the graph that the trend of Japan and Sweden old citizens is similar from 1940 to approximately 1992.',
#  'On the second place manufactured goods with 25%.',
#  'In 1990 the gradual decline slowed down in UK, USA and New Zealand, while Germany even experienced a significant incline of the income difference.',
#  'In sum, Agriculture, Industry and Services had 72, 23, and 105 workers respectively.',
#  'The least active category, in terms of time of exercising, is an age group over 75, the time spent on training does not exceed for both genders 30 minutes.',
#  'This feature covers United Kingdom and New Zealand.',
#  'As it can be seen form the first chart, the total number facebook followers was increased.',
#  'By contrast, in 1980 USA indicator demonstrated the second largest percentage distinction but in 1995 it fell significantly to 20 and became the third largest one, surpassed by UK.',
#  'The chart below illustrates changes of usage Facebook from 2013 to 2013 and the main reasons for ising it among males and females.',
#  'The first charts clearly shows that there are more visits abroad by the UK residents than visits to the UK by overseas residents.',
#  'The pick of this situatin was in 2005 year, when amount of boy with overweight became 25%.',
#  'Men category was still higher overall, thought it dropped slightly at the age group from 55 to 64.',
#  'The chart below gives the information about changes in worldwide investment in renewable energy.',
#  "One more point is Bachelor's degree.",
#  'Sharp increase was in the mobile usage, it can be explained by beginning of wide usage of smarthphones, but still the desktop usage did not decrease dramatically.',
#  'Although, like developed countries, they also experienced the downtrend in the last 2013 year.',
#  'They help us to communicate and share outr impressions.',
#  'The second chart shows the goods, that were transported by roads.',
#  'But during the whole period we can not see the stable increase of the invested money, it slightly flactuated and sometimes got higher, sometimes lower.',
#  'From 1980 to 1995 Japan, USA, UK, Germany and New Zealand go down with the percent of difference in income between men and woman.',
#  "Females were more willing to finish their education with eighter undergraduate diploma or with bachelor's degree than males did.",
#  'Another fact that the lowest numbers (1% and 3% respectively) in the Agriculture were also given by Australia.',
#  'To compare 2014 and 2015 we could notice that in Middle East and Latin America the unemployment rate bring down.',
#  'The same trend it can be seen in UK, where the income had fallen gradually from 35% to 24% throughout 15 years.',
#  'Overall, it is clear that metal is primeraly transported by rail, while food goods by road.',
#  'The bar charts below represent changes between men and women in using facebook and common reasons to use it from 2012 to 2013.',
#  'It could be clearly seen from the graph that Facebook is the major player in comparison with another web sites.',
#  'However, the graph highlight a considerable difference betwen travels abroad by UK residents and travels to the UK by overseas residents in the period from 1999.',
#  'heavy products such as metals and machinery products were rater transfered by roads, at the same time perishable products, that include chemicals and obviously foods were transported by trucks.',
#  'The amount of young men doing sports is almoas two time higher then men from the next age group, which is only 153000 hours.',
#  'Making a prediction about future, i would say that the investment rate in the world continue to decline.',
#  'Overall, the main trends found out are that men spent more time on doing exercises than women did and the age had indirect correlation with the time spent on leading an active lifestyle.',
#  'Overall, it is clear that the percentage of difference in income between males and females declined gradually in Japan, USA, UK and New Geland.',
#  'Overall, it can be seen that the smallest difference occured in Germany and New Zealand, while in Japan the difference is significant.',
#  'To sum up, global development is affecting every continent on Earth and it is very good.',
#  'In terms of Chemicals - it accounts to the average proportion and has almost the same percentage in both charts with slight differences - 11% and 16% respectively.',
#  'The trand is also never climbed suddenly.',
#  'Two countires showed less difference in earnings between men and women than the countries mentioned before.',
#  'To sum it up, the graps can be compared in the one striking point.',
#  'Gender salary gap was already quite small in Germany and new Zealand both not exceeding 25%.',
#  'Women use the social network for sharing prhoto and video content, entertaining such as watching funny pictures and learning about the ways to help others from 8% to 15% more than males.',
#  'In 2000 in Yemen number of children and number of adults were almost equal, however, in Italy amount of adults was more than amount of children on 47,3%.',
#  'The difference between growth of amount of overweight boys and girls is 4 percent.',
#  'It is clear that in Australia more female workers work in service sector, while in Indonesia the percentage of women working in agriculture and services is fairly similar.',
#  'The given charts illustrate information about the two types of goods transportation (by rail and by train) between Eastern European countries in 2008.',
#  'These two pictures depict the average level of temperature maximum and minimum in two cities: Yakutsk, Russia and Rio de Janeiro, Brazil.',
#  'Overall, the most popular sector of work in both countries among all genders is service sphere, the other economical sectors have less number of people.',
#  'To begin with, percentage of male workers is higher than part of female workers in Indonesia and Australia, but in Australia the servises sector has more women than men.',
#  'In the contrary, in 2000 in South Asia there was a great number of uneducated children, but this one decreased significantly and reached the bottom (4.8 millions of girls and 5.1 millions of boys accordingly).',
#  'However, the proroprtions of goods trasported by road were not the same.',
#  'Women of 25-34 and 35-44 age groups spent the same amount of time on exercising which equals 92,8 minutes, while men who were 25-34 years old tended to excercise more than the ones in 35-44 age group.',
#  'And in Africa amount of girls is higher than boys in 2012 and 2000.',
#  'Moreover, it is essential to notice that sector of agriculture in Australia compared to the same sector in Indonesia illustrates absolutely differt trends.',
#  'The table illustrates the proportion of man and women employes which works in three different sections in Indonesia and Australia in 2010.',
#  'According to the chart the worldwide unemployment rate is nearly 6% in 2014 and 2015.',
#  'As it seems in a part chart in 1990 a little more than a half of percentage of people had regular physical activity.',
#  'The level of deacrese is most significant in the UK - it is about 20.',
#  'Interestingly that at the 55-64 women spent more time doing sports that men on about 3 minutes.',
#  'Chemicals get more transported by road than by rail.',
#  'As can be obvios from the chart, the highest number of children without education was in Africa in 2000 (just under 45 millions) and the lowest was in the rest of world (under 25 millions).',
#  'On the other hand, level of investments rerenewable energy in world increased during 2006 and 2009 (from 100 to 168 bollions) and then sagnificant rocket from 2009 to 2011 and hit a peak in 2011 (279 billions).',
#  'Amout of detskop users was decreased for 20%.',
#  'The second shows to us for which reasons people use facebook and again deviding users on males and females.',
#  'Firstly, number of male workers are more than female workers likely in two times in Indonesia, whereas in Australia the proportion of male and female workers in industry is roughly three to one.',
#  'While in Australia the most of female prefer services sector, male workers work in industrial and services sector, when agrocultural sector is unpopular for both genders.',
#  'Finally, Sports and Health courses are more preferable by students of the middle age, 62 persent of all the students are people from 26 to 40 years old.',
#  'It is noticable, that all qualifications of men biggest than women.',
#  'Units are mesuared in percents.',
#  'The graph below suggest to us information about the changes of school assessment.',
#  'The overall structure significantly changed.',
#  'Significantly, a little proportion of both genders worked in agricultural sphere in Australia.',
#  'German was below those countries, that i mentioned but above New Zealand in 1980.',
#  'Both charts represent the information about goods which are transported by various ways: by rail and by road in Eastern Europe in 2008.',
#  'In the begining the male rate is more two times higher than female rate.',
#  'Comparing the data between 2000 and 2012, Africa 2012 indexes equal South Asia 2000 indexes.',
#  'However, since 1990s the number of people aged 65 and over increased from 3% to 26% in 2040.',
#  'It is clearly seen that the number of children without access to education commonly decreases.',
#  'But the smallest number of employers use can see in sphere of technology (800 in 1998).',
#  'China became the biggest fossil fuel consumer among the given countries at the maximum of almost 90% of the consumption of US in 1970.',
#  'The main trend is that men do sport and exercise more intense than women in almost every age category.',
#  'Represented countries as the USA, the UK and New Zeland showed gradual reduction of such percentage difference for the whole period of time.',
#  'Near The Japan located USA line.',
#  'The chart provides the information about the number of boys and girls who did regular exercises in 1990 and 2005.',
#  'And from 2000 to 2005 the percentage of boys with weight problems predominated, in 2000 it was 21% whereas the percentage of girls was lower on 1%, and in 2005 the number of overweight boys was higher on 3%.',
#  'Also, the line graph, that shows the income differencies in Germany falls down to 10% in 1990, but then it beggin to rise slowly up to 13 percent.',
#  'And by the diffirance of 5 years the percentage of overwaight girls increased by 2% but the number of boys increased only by 1%.',
#  'From the start in 2006 (about 70 billions) to the end of period in 2013 (about 130 billions).',
#  'Its rates were the highest in 2015, while other countries decreased gradually.',
#  'This charts below provides us with information on the transportation of goods in Eastern Europe in 2008.',
#  'Taking into consideration March 2012, it is notisable that there is difference between desktop and mobile use in approximatelly 110 millions of users.',
#  'In South Asia in 2000 there were 21,6 millions girls and 11,1 boys, who were without access to primary education.',
#  'The information that attracts the most of attention is that almost all over the age groups men have the higher average time spent.',
#  "So in South Asia and in Africa level of acces to primary edycation for girls in 2000 was higher the boy's.",
#  'What is more, the food products make up 30% of all road transported goods, but for the goods transported by rail this mark is 11%.',
#  'What conclusion can be drawn from all above is decreasing difference in income between male and female since 1980.',
#  'If we analyse women chart we can see that women does not have big difference between charts.',
#  'The second huge part of rail goods transoprting is manufactured goods which is exactly a quarter of the whole amount of goods.',
#  'In conclusion, although the number of all men and women decreasing, male part of population in England in 2012 was more activ than female.',
#  'On average one fourth of them visit these courses.',
#  'And, lastly, chart shows that women use FB for learning about how to help others on 10% more then men.',
#  'In contrast food products, chemicals and non-metallic minerals make up the majority of road transportation.',
#  'And finally, as can be seen in the first table, number of male workers is higher than female ones by 7 people in the services sector.',
#  'Although over half of the Facebook users considered photo and video sharing as the main reason of social networking, the proportion in this category has decreased from 54 percent in 2012 to 39 persent in 2013, which may be a consequence of increased app functional.',
#  'It can be seen that in the beginning of the year the temperature in Rio de Janeiro is very high and varies between 23 and 30 Celsius degrees.',
#  "Overall, the diffferences between two countries' employment sectors are obious and this can be explained by a number of factors, including historical background, gepgraphical position and place in the world's political arena.",
#  'In conclusion, these two tables clearly shows that in Australian people prefer to work in industry and service secors than in agriculure, but in Indonesia workers prefer agriculture and service sectors.',
#  'Turning to the first table, the biggest percentage of male workers in Indonesia interested in services, than in agriculture and the third most popular is industry respectivelly.',
#  'It can be seen from the chart that maturing makes british people less willing to do sport.',
#  'First of all, the percentage of energy wich was taken from fossil fuels in France was 90 per cent in 1970.',
#  'I should say that females have variety of main reasons for using Facebook.',
#  'In Yemen it around 40-50 per cent, in contrast in Italy it very small number.',
#  'Moreover, the highest point of word total is 279$ which occured in 2011.',
#  'The bar chart illustrates dependence of the age group to the use of three various social networks (Facebook, Instagram and Linked In) in the USA.',
#  'It is evident that the gap income between men and women of all countries decreased after 1978.',
#  'The first chart gives information about visits abroad made by UK residents and travels to the UK conducted by foreign residents.',
#  'As we can see, in Australia this sector illustrates almost minimal quantities, while indonesian, in contrast, put the agriculture on the 2-nd place in their occupations.',
#  'It is remarkable that the least present group in all three networks, which is 65 years old people or older, is equally present in LinkedIn.',
#  'However, there is a peculiar detail to be noted: while the investments in 2012 fell both in develped countries and in total, the developing countries actually hit their own highest score, and only then their numbers started going down.',
#  'On the other hand, India that was on the bottom became one of the leaders to the end of the period which we are seeing.',
#  'Althoug, men use Facebook for learning about ways to helpl people less than women - 35% and 25% respectively.',
#  'By contrast, only 39% of mem use Facebook for sharing media contetn.',
#  'The most big parties are for manufactured goods and metals.',
#  'Also, among five different type of qualifictions, it was the largest part of males, involving in different qualifications.',
#  'Although, the agricultural employment sector is much more widespread in Indonesia than in Australia, the second country shows higher employment in industrial sector.',
#  'Interestingly, that half of surveyed women thought that most important argument to serf the facebook is to share photos and videos.',
#  'Between 1940 and 1980 the percentage of aged people in Sweden and the USA was growing steadily: from 9% to 15% in the USA and from 7% to 14% in Sweden.',
#  'The vertical axis depicts the gender.',
#  "Only the European Union had a trend of rate's rising.",
#  'The chart shows that there is a dramatically decrease in sport activities between the two younger group, so for example men aged 25-34 did almost half as much sport as those aged 16-24.',
#  'Next came a rapid and remarkable fall to the level of 214 $ bn.',
#  'Nevertheless, the indices of mobile Facebook remaned significantly lower than those of desktop Facebook, reaching a peak at about 95 and 150 million of users, respectively.',
#  'The tables show the employment of workers in Indonesia and Australia shared by gender.',
#  'This chart gives the information about the income differences between two genders in five nations during 15 - year period of time, from 1980 to 1995.',
#  'By far most popular job field for men and women in Indinesia is senices.',
#  'Chemicals take 16 percent, non-metallic minerals take 13 persent and matals take 11 percent.',
#  'Minimum temperature is approximately -40 degree in two months: January and December.',
#  'Two presented table charts are highlighting the difference in labour force perticipation between men and women in two neighbouring countries - Australia and Indonesia in 2010.',
#  'Surprisingly, the tables have turned, and in 2005 the percentage of overweight boys was higher than the girls one by 3 percent.',
#  'Also worth pointing that Insustry in both countries did not overcome 50% even together.',
#  'According to the prisoners in the USA, there were 33 percents of white people, which is 34 percents smaller than the number of non-white people.',
#  'The charts below show the main reasons for study among students of different age groups and the amount of support they received from employers.',
#  'According to the graph it will be a great rise in the proportion of people aged 65 and over in Japan from 10% in 2020 to 27% in 2040.',
#  'The second bigger measure was in postraduage diploma.',
#  'The increase of the percentage of overweight girls and boys was not dramaticaly fast.',
#  'In Australia female workers tends to work in service where work almost every 9 of 10 females than agriculture where only 1 of 100 females work.',
#  'The most popilar rail transporting industry was metail industry, however, food production was the leader of road transportation in 2008.',
#  'In conclusion the transportation of goods in Eastern Europe in 2008 was very good.',
#  'But it shoud be noticed that this age-category deliberated in the last type of courses.',
#  'The least meaningful reason to use facebook is to learn about ways to help other for men and women.',
#  'This is the only sectore in which the ratio of people in Indonasia is higher.',
#  'Overall, it is clear that the transportation by rail was more suitable for goods which were more heavy and did not need to be delivered in short periods, because they did not have time, when they could be used.',
#  'The table shows amount of people who usually did sports in 1990 and 2005.',
#  'And manufactured goods was increased from 25 percent to 28 percent.',
#  'The chart provides information about the unemployment rates in different regions of the world in 2014 and in 2015.',
#  'The graph is showing the amount of energy, gained from fossil fuels by five nations.',
#  'To sum up, the differences in post- school qualifications according to gender are serious enough, that is why it is hard to headline the whole trend of the graph.',
#  'With respect to developing countries, there was an increment from 2006 to 2012, but saw a slight decrese in the last year.',
#  'The pie charts show details of transportation different produced goods by train and by motor in Eastern European coutries.',
#  'But unfortunately underground of London is not the most popular because the biggest amount of visitors (1927) has underground of Tokyo.',
#  'In Middle East and Latin America this level is getting lower but this change is not getting bigger than two percent.',
#  'The sector industry is smallest sector In Indonesia.',
#  'To conclude, as it may be seen from the provided chart the goods which transported by railway very often is metals; however, by road - food products.',
#  'The percentage of unemployment rate on Middle East and Latin America decreased so the situation changed in the positive way.',
#  'The line which represents the decrease of such difference in Japan as in the region with the most significant difference in income between men and women shows 40% at the year 1980 which is twice as high as the perecetage shown in the same year in New Zealand.',
#  'Seeing funny post is also popular more for women that for men, so it is 43% against 35%.',
#  'Now, according to information in table, we can see a growth of percentage girls and boys who did regular physical activity.',
#  'Only in one of the age groups women doing more sport than men from 55 to 64 years, in every other groups men are having leadership.',
#  'Moreover, in graph and table we can see, that number of boys wich has problems with thier eght is bigger, so as a number of boys whos rugalrly doing exercises.',
#  'This graphs shows us the information about Facebook company and how, and also why their users using Facebook.',
#  'Investments in developed countries are higher, but less stable.',
#  'For both genders excercise time has fallen in almost 10 times from the maximum to the minimum point.',
#  'The presented two lines graphs illustrate information about temperatures in two cities: Yakutsk, Russia and Rio de Jeneiro, Brazil during a year.',
#  'The same situation is wiht chemicals.',
#  'To sum up, there is a downward trend, which idicates that elder people from both gender groups did less exercises than younger people in 2012.',
#  'Newertheless both percentages were increasing each five years, fluctiating roughly in the same percentage.',
#  'The changes in the rest of world were like in Africa.',
#  "In Australia it's 65% of male and 88% of women and in Indonesia it is 56 and 49 percents respectively.",
#  'According to the figures, people of all ages spend a good part of their leisure time on sport activities.',
#  'Developed countries started investing money in renewable energy in 2006 with a sum of approximately 70 billion dollar, while developing countries invested only 30 billion dollars.',
#  'From 1995 to 1999 the number of minutes of local calls was increasing from 70 billions to 90 billions.',
#  '87% of youth spend their time at facebook.',
#  'Graphic shows that level of overweight boys and girls is quiet the same.',
#  'Speaking about food products, the opposite situation may be seen as long as it is the most popular kind of goods for the car transfer with 30% of total volume and one of the least popular product for transferring by railroad.',
#  'There is also a significant persentage growth of boys and girls from 1990 to 2005 who are active.',
#  'But Yemen has a lot of children that about half of all population of this country.',
#  'The UK collages in 2012 Students who choose to study science courses were 650 students altogether where 40 years old students are 15%, 26-40 year old are 30% and 18-25 year old students are 55%.',
#  'Both numbers are 10 times higher than the result of people over 75.',
#  'The combined line graph and bar chart show the investments in renuable energy of developing and developed countries all around the world between 2006 and 2013 years in billions of dollars.',
#  'In 2008, as showed on graph, in Europe chemicals was transported in equal amoun by roads and by rails, 16% and 11% correspondingly.',
#  'The main trend was that the percentage difference in earnings deacreased steadily in all presented countries.',
#  'The graph shows the number of facebook users in March of 2012 and 2013 who prefer mobile or desktop versions.',
#  'But there is a significant difference between this countries in Services sector - the number of female workers in Indonesia is 7% smaller then the number of male workers, while the number of female workers in Australian Services sector is 24% higher then the number of male workers.',
#  'So, according to the statistics on the world as a whole, we can generally see a rise in finance investment from 2006 to 2010, with some modest pause in 2007-2009, which was followed by a gradual growth right from the 2009 and up to 2011.',
#  "Although the graph, showing temperature in Rio doesn't have so sharp peaks, line reaches its highest point in January, when the temperature is about 30°C, looking at maximum line and about 23°C by minimum.",
#  'The graph shows that in 1980 the difference of outcomes in the former equals approximately 35-40%, as well as in latter this feature is 15-20% lower.',
#  'From 55 to 64 that is the only period their women spent more minutes on exercise in 2012 but the difference in numbers is not as big as in the period 16-24.',
#  'March 2012 began at approximately 150 million of people that were using desktop version and almost 140 million who downloaded the mobile app.',
#  'Having to said that services sector had the mojority percentage in both countries.',
#  'In the begginig, developed countries were invest near 60 bn but after it rose sharply to 151 bn from 2006 to 2010.',
#  'The given diagram represents how was changing the percent of the population aged over 65 years in the period from 1940 to 2040 in Japan, Sweden, and USA.',
#  'The gratec change in percentage is only from %.',
#  'The same 15% of electricity is used for both lighting, TV radio and vacuum cleaners, food mixers, electronic tools.',
#  'The bar chart shows the avarege time men and women spent doing sports.',
#  'The given pie charts below illustrate us an information about the transportation of goods between countries in Eastern Europe in 2008 year.',
#  'The population of Yemen in 2000 was presented mostly by children aged up to 14 years, which were little more than a half of population (50,1%), and teenagers and middle-aged people.',
#  'Between 2008 and 2009 the amount of investment was fluctuating but after the peak in 2011 it was decreasing dramatically to the quantity of 214$ billion invested by all countries in 2013.',
#  'The highest point in this coutry was reaches in 1985 with the value of just above 40 per cent.',
#  'On the other hand, Australia has the same large percentage of workers in services sphere - 65% for men and 88% for women.',
#  'Graphs represent several reasons for using Facebok, such as posting photos and videos, receiving updates, seeing funny posts and learning about ways to help others.',
#  'The same tendency was in China - 4,8 billions of US Dollars and 0,5 billions of Dolllars.',
#  '28% of this kind of goods were transported by cars and 25% of this one were transmissed by trains.',
#  'By contrast, in agricultural sector the number of employees is extremely low.',
#  'Overall, there are different pattern of transportation by rail and by road.',
#  'But the proportion of boys and girls does not changed.',
#  'Pie charts represent the proportion of consumers demandings shipped between east Europian countries in 2008 by rail and road.',
#  'As we can see, In Italy 15-59 years people are 61,6% of population, the minority is youngers at the age under 14.',
#  'But while the agriculture sphere takes the second place in the employment statistics, it is the less popular place to work at in Australia.',
#  'We can see that this graph is deacreasing.',
#  'In 2014 european contries had 7,5% unemployment rate.',
#  'Data divided into 7 age groups and 2 genders.',
#  'In Italy this age group comprised one fourth of the population.',
#  "In the meantime, women's involevement in sports at the age over 75 is just 10 minutes, that is less on nearly 10 minutes than man's one.",
#  'So in the industrial sphere there are almost twice as many men (Their number is 15 percent) as women (Their number is 8 percent).',
#  'There are two charts for Yemen and two charts for Italy, that give us an information about persantage of people under 14 years old, 15-59 years and people elder then 60 years old.',
#  'In indonesia 29 men had a job in agricultural area, 15 men worked in industrial sector and the majority of male workers had a job in services.',
#  'The least popular reason to use Fasebook is learning about ways to help other.',
#  'It can be deduced from the graph that sharing photos and videos was the main reason of using facebook among man and women, but the persentage of women was considerably higher - 54% in comparison with 39% of men.',
#  "To sum up, the main difference in the transportation of goods betwenen the rail and the road, lies between food, which needs mostly short-term transportation and metalls and machinery, which can't be transportated by large amounts on roads.",
#  'The persentage of women doing it is 54% and men is 39%.',
#  'Important dicreasing among counries happend in next year - 2012.',
#  "As it can be observed, physical activity gradually decreased with the growth of respondent's age.",
#  'Overall, from the 1980 to 1995 the difference of earnings in the USA and Japan was declining.',
#  'To sum up, although children are able to the physical activity more than earlier, there is trend that overweight among boys and girls increase during all period.',
#  'These types transportation play different role in transportation of goods between countries.',
#  'The amount of Desktop users decreased but only for 15 millions of users, which is only ten percent of all.',
#  'Agriculture is far less common choice for men in Australia.',
#  'At the age of 25-34 to 35-44 female respondents spent the same number of minutes on doing sports - 92,8 minutes.',
#  'In each chart, we can see that there are two major section which is transported by a particular way.',
#  'Countries in 1940 included only 5-10% of old people (65 years and over); but recearchers suppose that amount of this people in population of countries will be about 20-30% to 2040.',
#  'It is noticeable that in 2012 more often users prefer Desctop while in 2013 mobile became more preferable gadjet.',
#  'in 2011 the developed countries reached absolute pick in the investment in renewable energy and the value almost twice more comparing to the investment value of delevoping countries in the same year.',
#  'The largest number of goods transported by road is food product (30%).',
#  'Becouse of this fact we can see a litle fall in 2009 of total investments from 171$Bn to 168$Bn.',
#  "In womens' case, it can be seen that only 1% of female workers has a job in agriculture sector, while most of women are employed in jobs, considering services.",
#  'However, from 2011 to 2013 rapid downward trend can be seen.',
#  'Only Manufactired goods and Chemicals increase their parts by 3% and 5% relatively from chart 1 to chart 2.',
#  'Percentage of overweight boys was the highest throughout the period, rising from 57 per sent in 1990 to 87 per sent in 2005.',
#  'There were 74 and 26 per cenr respectively.',
#  'Other popular reason which users called is receiving updates.',
#  "Secondly, there is an another tendency - most of women prefered to take the undergraduate diploma or the bachelor's degree: 70 percent against 37 percent approximately and 53 percent approximately against 48 percents approximately.",
#  'Overall, in 1990 there was a clear carrellation between number of kids of a particular sex who did physical activity and overweighted ones.',
#  'We can see it on the graphic, by scale "for interest" grows rapidly from 25% after 30 - 39 and finishing with 70% in cathegory over 49.',
#  'These changes created balance and as a result, Worldwide unemployment rate did not change in 2015.',
#  'Overall, it is clear that the oldest underground railway system is in London, so kilometres of route compose the highest point, 394 kilometres.',
#  'In 1995 two countries reached the recording 10 percent of difference.',
#  'Talking about the rail, it is especially popular for transportation of metals (35%) and manufactured goods (25%).',
#  'The first chart shows the number of users who used two vesions of the site, desktop and mobile, in March 2012 and March 2013.',
#  'Then, men at age of 55 to 64 did less exercises than men at age of 65 to 74 in about 8 minutes.',
#  'However, in age group of 55-65 people do it some bit less then in age of 65-74 and this difference is about 10 minutes.',
#  '3 regions had the similar values in this period, but 1 region had a little change in his percentage numbers.',
#  'Regarding others countries we see an oscillation in the persentage difference in earnings between men and women.',
#  'The second place on the chart take postgraduate diploma, it has 30 percent less than skilled vocational.',
#  "There are two momets - in 2009 ans in 2012, when developed countries redused their investments, but developing countries' investments kept growing.",
#  'The end of 2012 indices fell on 10 million.',
#  'Than in 2012 desktop was more popular from women and in 2013 become less popular in comparing with mobile and showed significant decrease from 140 millions of users to 60 millions.',
#  'On the other hand, the minimum of proportion the countries had in 1940, which was about 5-10%.',
#  'The younger people are, the more they spend time on doing exercies.',
#  'Although, let us take a look at the second chart where we can see that the overall number of usage of Facebook are women, ecxept receiving updates in which the percantage of using is the same 39%.',
#  'Then dynamic of men sport interest slowly fell by the ages 55-64.',
#  'Overall, developed countries have invested the most troughout the period.',
#  'According to the chart, the number of girls and boys without opportunity t go to primary school equally in every region.',
#  'Meanwhile the use of dekstop version is pretty throughout the period.',
#  'More than a half of male workers and approximately the majority of female workers are have their place of occupation in such field.',
#  'These network give people easier ways to have fun and sgare information with each other, that are the main reasons for all genders to use Facebook.',
#  'There is also a line of world total, all this information illustrates the tendentions of investment in different countries between 2006 and 2013.',
#  "Furthermore, the situation in industrial arena of these two countries is pretty similar: male workers are dominating if we compare with female workers' point.",
#  'The graph represents the investment in renewable energy over 8 years and shows the differnce in the investement in developed and developing countries.',
#  'The first tendancy, which one can notice on chart, is the quantity of males, with skilled vocational diploma 9 times higher than females with such kind of diploma.',
#  'On the contrast, there 45% of students who are in there 40 and above among people studying on the art courses.',
#  'The USA population increases from this moment from 16% to 23% in 2040 and population of Sweden grows from 18% to 25% in 2040.',
#  'For instance, more than half of science cources students belonged to age group "18-25 years old", while majority of arts cources attenders, 45%, were people older than 45 years old.',
#  'The two pie charts illustrate the proportion of several types of good, transported in Eastern Europe by rail and by road within a timespan of one year.',
#  'This pie chart illustrates the percentage of conveyance of products by rail and by road throuth the eastern european countries in 2008.',
#  'The tendency is similar with the world total, but in case of developed countries, its investment was approximately three times bigger than in developing ones, about 75 and 25 billion dollars respectively in the year of 2006.',
#  'To sum up, there are significant differences betweens goods which are transported by rail and road.',
#  'However, it must be said, that situation in USA changed more dramatically, The percentage halved in size, while the percentage for UK reduced only by 12%.',
#  'The graph provides information about investements in renewable energy from 2006 to 2013.',
#  'Here we can see diferents between Africa, South Asia and Rest of World from 2000 to 2012.',
#  '87% of adults from 18 to 29 use Facebook, as well as 73% of adults from 30 to 49, 63% of the age 50 to 64 and 56% of users older than 65.',
#  'For example, average young girl at the age group 16-24 spends 114,1 minutes on sport which is 2,5 less than the time expenditure of a male from the same group.',
#  'In contrast, USA showed the highest results during the period between 1940 and 1990, demonstrating a stable growth from aproximately 9% in 1940 to about 14% in 1990.',
#  'Overall, it can be seen that number of men and women that using Facebook experienced a downward trend from both types of devices, although modile devices showed less surge.',
#  'The difference in income in USA and UK was quite similar, at 30% and 33% at the beginning and 20% and 23% at the end, respectively.',
#  'There is a big difference between men and women in age category from sixteen to twenty four.',
#  'We can see that the main reason for using facebook among women and men is sharing photos or videos, while the lowest point is to learn about ways to help others.',
#  'But in 50 years children will be grown up, and they will became oldmen, and the level of young people will decrease.',
#  'In Indonesia industry is at the second place, whereas in Australia it is on the third one.',
#  'In 1990 in Germany war reached global minimum 10 persents and the hierst value was reached in Japan it was 35 persents.',
#  'Then it slightlightly decreased by the year 2009 to approximately 100 billions of dollar.',
#  'These pie charts illustrates the ratios of various goods transported by rail and road between Eastern Europe countries in the year of 2008.',
#  'But the gap in time between both genders becomes less with aging',
#  'However, the percentage of Manufactured goods are very similar in both types of transportation and made up approximately 26%.',
#  'By contract, more than half of women consider that sharing photos and videos is the main reason to use this network, while only 39% of men support their idea.',
#  'Generally, reasons for using Facebooks are common but different number of males and females choose different causes.',
#  'In the Germany, the difference in income between different genders has plummeted sice the early 1980s.',
#  'Additionally, the proportion of female students adopting a bachelors degree was also higher than that of the opposite gender, with approximately 55% and 45% respectively.',
#  'After a period of stagnation between 2008 and 2009 it rose dramatically and reached a peak (279 billiom dollars) in 2011.',
#  'According to the projections for 2050 it is going to decline to the level of 46,2%, whereas the percentage of old people is going to increase.',
#  'The following chart illustrates the propotion of men and women who did sport and exercise in England in 2012 divided into age groups.',
#  'However, the unemployment rate reaches its peak in N. Africa equally in 2014 and 2015 with 12,5%.',
#  'Also, woman prefer to learn about ways to help others, but only 25% of men do it.',
#  'Overall, judging by the graph for the total worldwide chanhe in energy investment, one can observe that there was a continuious growth up until 2008, when the amount invested hit a plateau, which was followed by a rapid increase in 2010.',
#  'These three countries are USA, Sweden and Japan.',
#  'Only 11% of women worked in insudtry area, while men had 32% in this sector.',
#  'the smallest amount of passengers is in Koyoto and Los Angeles, 45 and 50 millions of visitors in the year.',
#  'If looking in the chart then we vision what boys and girls in the 2012 years going to school very few, then in the 2000 years.',
#  'I hear that Renewable Energy technologies is worse that usual Energy technologies and have bad affect on surrounding.',
#  'Speaking of similarities between these two tables, there are more men than weman in agriculture sector in both countries.',
#  'The table and chart below illustrate the percentage of girls and boys who had problems with their weight in Canada from 1985 to 2005 and the percentage of teenagers who did regular physical activity in 1990 and 2005.',
#  'The same tendency to Middle East can be observed in Latin America.',
#  'Unemployment decreased from 11 to 9,6.',
#  'But at the end of the decade in all countries difference between income of men and woman drops severly by 15 percentage ponits in comparasion to 1980.',
#  'Percentage difference in USA in 1980 was about 40 percent while at the very end of giving period in fell to 20 percent.',
#  'Talking about the second graph, we can see the diagram of "reasons using facebook".',
#  'If we looking on the percentage of boys with same problem, this statistics increase slightly between 1985 and 1990, but from 1990 to 2005 it has dramatically increase on 4% per 5 year.',
#  'As it is seen from the diagram the number of people who prefer to use desktop at the beginning of the period reaches approximately 150 millions while the number of mobile users exceeds 40 millions.',
#  'Among male working in agriculture there are only 29 per cent in Indonesia, whilw in Australis it iakes only 8 per cent.',
#  'In Germany the summ of money dedicated to prind edidions remained stable- 6 billion US dollars in both 2014 and 2018.',
#  "But Germany at the end of it's curve line before the 1995 had returned to the 4th place with a slight increase.",
#  'To make our own analysis, we will look to all the data presented separatly.',
#  'The number of people who come to study in a library has fallen dramatically from 1990 to 2000.',
#  'In 75 years old man spent only around 29 minuts on sport, while woman spent a way over this amount, 10 minuts.',
#  'The quantity of people there is almoust 50 persents of al workers in these three sectors.',
#  'The gap between amount of time spent on sport is downsizing until 55-64.',
#  'According to the first chart, it is possible to say that metals was the most popular catgory to transport in 2008 in Eastern Europe.',
#  'It should be noted, that the lowest percentage of difference in earnings (10%) was recorded in Germany in 1980.',
#  'In 1995 the amout of overweight girls and boys leveled out and increased two-fold by 2005, while in 1985 it was less than 15 percent.',
#  'Secondly, students who are in category of 26-40 years old have the main part of Sports and Health courses (62 percent) whereas the same category has the least percentage on the chart about Arts courses (25 percent).',
#  'Moreover, there is a significant difference in delivering metals goods between countries in Eastern Europe: 35% by rail and only 11% by road.',
#  'On the contrary, the rate in EU had increase of 0,4%.',
#  'Overall, due to the forecast for 2018, eBook market is going to become more popular: in the USA it is predicted to grow up to 8,5 billions of annual profit, while in Germany and China it will rise to 0,5 billions and become 1,5 and 1 billions respectively.',
#  'Overall, statictics of British people doing sports shows that men are generally more active in doing sports than women and average time spent on sport and exercises decreases while people become older.',
#  'Overall, majority of people used to use desctops to enter the Facebook rather than mobile phones.',
#  "let's talk about similarities.",
#  'The charts illustrate how many goods were tranported by rail and road in Eastern Europe in 2008.',
#  'The difference between the biggest and the least indicates did not reach more than 15 degrees.',
#  'It measured in persentage too.',
#  'So, generally speaking, men prefered to have undergraduate diploma.',
#  'The vertical one shows that the most of the users using a desktop version.',
#  'In the year of 1980 all presented countries started from their pick in percentage difference, except for Japan.',
#  'Besides, the most significant change in the unemployment rate within the years has been illustrated by the Middle East.',
#  'To sum up, as a result of fast growing up in Japan in the end of the period, Japan was the leader among all countries of proportion of population aged 65 and over.',
#  'while the table shows percentage of the same children but those who did regular physical activity in 1990 and 2005.',
#  'To sum up, according to the graph it is clear that there was an upward trend of changes in investment in renewable energy until the 2011.',
#  'There is a tendency that an investment in this field reached a peak in 2011 with just one exception (in developing countries the peak was in 2012).',
#  'The bar chart gives information about the average time spending on sport activities by the British in 2012.',
#  'This chart and table illustrate the amount of boys and girls who had overweight in Canada during the 1985 to 2005 and amount of young people who did exercises between 1990 to 2005.',
#  'The bar chart under analysisis describes the changes in the number of overwight children over a period of twenty years between 1985 and 2005 while the table under consideration demonstrates the changes in the number of children doing sports on a regular basis over a period of fifteen years between 1970 and 2005.',
#  'It can be seen that the major of people in both countries work in service sphere.',
#  'Even though girls became much more active in 2005 comparing to 1990, still boys outperform girls in regular phisical activity.',
#  'While the proportion of men interested in this is lawyer, 25 per cents.',
#  'The chart of percentage of girls and boys who did regular physical activity in 1990 and 2005 actually shows that with time they did more physical activity.',
#  'While Japan had the highest proportion of income between both genders all over 15 year period, the group of Germany and New Zeland, on the contrary, had the lowest percentage of earnings.',
#  'People who are under 26 years like rules go to university for career.',
#  'The difference in UK at the beggining was about 20% and about 1982 it exceeded that for USA.',
#  'Speaking of men, more than a third part answered that the main reason for using Facebook for them is also an ability to share this specific type content.',
#  'However, in other countries there are some of them.',
#  'However, in 1985 the percentage of girls were bigger but in 2005 the 25% of boys and 22% of girls have problems with weight.',
#  'Also, the difference between maximum and minimum average temperature remain almost the same through whole period, while in Yakutsk difference decreased in half in january and december, comparing to july.',
#  'however, South Asia in 2000 is an exception.',
#  'The illustrations demonstrate proportions of goods transported by rail and by road between Eastern Europe countries in 2008.',
#  'All informatin divided into 2 gender part.',
#  'Also thereis a table below that gives us a look on the persentage of girls and boys who did some kind of phisical activity regulary between 1990 and 2005.',
#  'Then it considerably decreases till the age of 55, when there is another fall to 52.7, which twice as small as in the previous cluster.',
#  'Secondly, in Latin America the level of unemployment plummeted too (from 6,8 to 5,8).',
#  'Overall, every way of transportation specialize on different goods.',
#  'In this time more people preferred to use mobile version.',
#  'In this report i am going to explain the information that is given in two tables above.',
#  'Overall, we can see that the amount and type of goods delivered between countries vary to a certain extend depending on kind of their transportation.',
#  'On the over hand, the percentage of sporty girls rose from 51% in 1990 to 77% in 2005; and atatistics of boys who did regular physical exersices increase from 57% in 1990 to 87% in 2005.',
#  'Overall, it is noticable that percentage dramatically changes for every type of good (chemacals, non-metallic minerals, food production, machinery, metals and manufactored goods) according to the chosen way of transporting.',
# ...
#  'At the beginning of the period, in 1980, the difference in income between men and woman is as follows: 40 percent in Japan, 38 percent in USA, 36 percent in the UK, 23 percent in Germany and 20 percent in New Zealand.',
#  'It can be seen that part of countries has the same level of unemployed people, such as N. Africa and S. Asia.',
#  'Moreover, it is quite important to mention that the amount of students at every course is approximatelly the same so it can be said that there is no correlation between the amount of students and the main topic of the course.',
#  'The two graphs provide the information about how people used Facebook in the period between 2013 and 2013 and why different ganders used this social network.',
#  'Overall, the tendency is the following the older the person, the less time they spends on physical exercises, because the average sport time gently declined through the ages.',
#  'Females are not interestred in this sphere, that is why the number of males rather big up to 90% of all gender.',
#  'Also, time of doing sport of women from 25-44 states at the same position.',
#  'With regards to the remaining methods of percentage of both sexes who did regular physical activity and overweight, there was a slight increases of overweight girls and boys of about 2-3% and it was 16% of both sexes in 1995.',
#  "In this essay I'm going to summarise the selected information about them and will try to give comparison analise about them.",
#  'Reading newspapers accounts only 5% in 2000, whereas it was 15 in 1990.',
#  "It is interesting to point that when IPhone's popularity fall up to 60% Samsung's one is the biggest this year.",
#  'If we give a small analysis to thies investments, we can see that the lowest number was about 75$ Bn in the 2006, and the peak was in 2011 and count 175$ Bn.',
#  'Moreover, the smallest transported part is also different: this is machinary in category goods transported by road and non-metallic minerals in goods transported by rail.',
#  'Before this, both in 1985 and 1990, the rate girls was higher tnan boys and accounted for 12 per cent (in 1985) and 14 (in 1990), when boys contituted 11 (in 1985) and 12 (in 1990).',
#  "It is also easy to notice that the agriculture is much less popular in Australia as far as only three percents of men and one percent of women are working in this sector comparing to Indonesia's twenty nine and fourty nine percents relatively.",
#  'Old people from 60+ years take a quite big portion in Italy for 2000 as for 2050.',
#  'First, we can spot that the World total spending was gradualy increasing until 2011 (from 100 billion in 2006 to 279 billion in 2011) with a hardly notisable decrease 2008 and 2009, where it almosed plateaued at the 170 billion mark.',
#  'On the contrary to the younger group, 40 years old and above students are not so interested in sports, approximately a quarter.',
#  'To compare with these two regions rest of world has less people who had not access to primary education.',
#  'By the way, only one quater and almost one thied of all students are attending art and science courses respectively with the age group of 26-40.',
#  'Food products and chemicals products have the equal shares, which are 11%.',
#  'It is cleare that the level of population rise for all this period in all countries.',
#  'As it can be seen from the chart, the average time spent doing sport activities in England in 2012 by age and gender is illustrated.',
#  'The points reached a peak in 2005 and was 22% that only 3% less than boys percentage.',
#  'In 2012 still about 30,6 million girls have not access to primary schools.',
#  'The chart shows a comparison of two kinds of towards transportation between parts of Eastern Europe in 2008.',
#  'There was a noticable increased in the diffrence of salary between male and female in Japan from 1975 to 1985.',
#  'Then after a smal drop investemnt come back to getting up and toched its "peak of the montaion" in 2011.',
#  'National and international fixed-line grew stadily from slightly less than 40 billion in 1995 to 70 billion at the end of the period.',
#  'Ba far, using Facebook on the desktop bacame more popular than mobile.',
#  'Overall, acccording to the graph, it can be seen that the difference in income between men and women became smaller over the period.',
#  'Chemicals, Food one and second one had 11percent.',
#  'There was a bit more than 11 million of boys without primary education in that region in 2000, but by 2012 it lost around 50% of the initial level.',
#  'Speaking about differences according to gender, men tend to do sport and exercises more offten than women.',
#  'In sark contrast to this, the pecentage of boys improved from 11% in 1985 to 12% in 1990.',
#  'The least famous sphere of the employment was agriculture in Australia.',
#  'It can be concluded from the graph that seeing funny posts is more interesting for women that for men.',
#  'The situations in USA and UK looked similiar.',
#  'In 2000 the most problematic region were Africa and South Asia where aproximatly seventy-five million children could not go to school.',
#  'Overall, it is clear that percentage of manufactured goods were almost the same and one of the largest pieces of both charts.',
#  'As for predictions for Yemen for 2050, they will be rather optimistic, because the central age group (15-59) will be about 57,3% of all population.',
#  "The next age group of people aged 15-59 years performs 46,3 per cent of Yemen's population.",
#  'The chart below shows that number of children without acces to primary education decrease in whole world.',
#  'Only in age between 52 to 55 women spent more time on phisical activities.',
#  'It is immediately obvious that there are some quite significant differences between two charts.',
#  "As for the Bachelor's degree, the persentage of males and females was particularly the same in 1999.",
#  'The least popular sector in Australia is Agricultural sector, at the same time more then quarter of men in Indonesia work in this sector According to this table, easy to mension that male and female population of country works in every sector practically in the same proportions.',
#  'Facebook and Instagram are both more popular among yonger people and less popular among older ones.',
#  'As it can be seen about 90% of men got skilled vocational diploma, at the same time just over 10% of women had it.',
#  'And the second graph show changes in the main reasons for using Facebook among woman and men.',
#  'Overall, even from the first look, we can spot the brilliant progress of Japan which used to be the worst of these three countries in 2040 and managed to become the first by 2040.',
#  'The figure compairs how people have sport activities in UK in 2012.',
#  'Firstly, we can see, that younger you are, you spend more time for physical health, than you are over 75 years old.',
#  'It is intresting to notice that nearly equal parts of the manufactured goods was transported by both means of transport, 25% by rail and 25% by road.',
#  'Moreover, as a rule, men spent on sports more time than women.',
#  'As we can see, each age group prefered each category of cources to a non similar extend depended on how old they were.',
#  'Overall, it shows that more users choose mobile version of Facebook compared to previous year, but still less than website, also chart demostrate that women are majority on Facebook because of larger percentage of using.',
#  'What about the reasons, lots of people use the Facebook for sharing photos and videos.',
#  'In addition, there is minority amount of women working in the agricultural sphere.',
#  'In other age groups the decline was more or less steady.',
#  "Just in one year Facebook's members started using mobile phone on the 40% more often than in 2012.",
#  'Secondly, the smallest amount of percentage was in machinery with 2% in transported by road and with zero percentage by rail.',
#  'As it is evident, employment division is currently affected by various aspects, but some categories such as gender is different regions influence on working clusters.',
#  "The most radical fluctiation among all is fall of the Middle East unemployment rate's percentage from 11 to 9,6 over a year.",
#  'In general, in the beginning of the last decade of 20th century, public libraries were visited by over one third of a billion citizens.',
#  'Using this web-source with desktop has declined by March 2013 from 150 million of users to 135 million, whereas this number rose sharply from 55 million of users to 95 million with using mobile phones.',
#  "On the graph we see that large amount boys and girls wish didn't get education in Africa.",
#  'Secondly, developing countries invested more and more money in renewable resource, during the period from 2006 to 2012, but in 2013 the mentioned parameter declined on about 10 bn $ and reached the 90 bn $.',
#  'In detailes the number of people, which are 15-59 years old, was more in Italy and it was 61,6% when in Yemen this figure was 46,3% in 2000.',
#  'Overwise, industry sector more popular in Australia.',
#  'But between some years there are small decreases of the population.',
#  'However, percentage of men who use Facebook is higher, 54 against 39 for women.',
#  'Here the amount of time men spend doing exercise is bigger more than twice compared to the women: 282,1 minutes vs. 114,1.',
#  "In the table, after 2000 the major level of ebesity increased, but boys' population had more fat guys than its opponents.",
#  'It can be clearly seen that the USA are a prominent leader in book selling.',
#  'Next to metals is manufactured goods, which take one quater of whole amount.',
#  'The diffrence in income between men and women reached the pick in Japan approximetaly in 1985.',
#  'Than there can be seen a parallel between the growth of age and the rise of indiffernce for social reds among users.',
#  'Finally, nevertheless different changes in populations, which can appear according to predictions for 2050, it will right to say that whole population will become older, there will be less teenagers and more old people.',
#  'From the first chart we can see, that decrease in use of Facebook from desktop computers is rather low than increase in cellphones (cnange at about one fourth).',
#  'At the first glance it is absolutely cleat that, during this time there was a lot of signigicant fluctation.',
#  'It is easy to see that industry field is not popular in Indonesia for workers.',
#  'We can see that children and teenagers (people from 0 to 14) in both country lose their position in proportion of population.',
#  'It consist of 65 mens and 88 womens.',
#  'Nevertheless, it increase rappidly to the 2013 and similarly drop to the same period.',
#  'The difference between the highest and the lowest point is extremly big, from 2006 to 2011 investment in renewable energy rises by 179$ Bn.',
#  'It is interesting to notice that the amount of manufactured goods, transported by road, is nearly similar to amount, transported by rail, the first one is only 3% higher.',
#  'There is big difference in number of elder people (60+ years) between two countries: 3,6% in Yemen and 24,1% in Italy.',
#  'By looking at three charts, one may notice a strong correlation between the type of courses and the age of the majority of attendants.',
#  'In comparsion Indonesia has 29 and 43 percents of workers in Agriculture sector.',
#  'The least popular reson for using Facebook is learning about ways to help others.',
#  'We can conclude that agriculture is more developped in Indonesia than in Australia.',
#  'While the highest persentage that girls reached in 2005 is aproximattely 22% / Generaly speaking, the percentage of children of bouth gendersignificaly increased over fifteen years.',
#  'The number of them was 54%.',
#  'To sum up, we can see that the graph illustrates a prediction by 2040.',
#  'Most women in Australia work in the service sector, 88 percent in total, As for men, this vaue in not so great but also more than half.',
#  'The figure of money, which will be reached by selling printed and eBooks in this country, is around 16 billions US dollars.',
#  'The tables illustrate the percentage of employees diveded by sex in two countries: Indonesia and Australia.',
#  'At the same time an amount of people using mobile version of Facebook had significantly risen from less than 60 millions of users in March 2012 to almost 100 millions in March 2013.',
#  "The amount of boys with obessity also hit a peak in 2005 but was less than girls' rate and made up 22 percent.",
#  'Overall it can be seen that the biggest market of all kinds of books is located in the USA.',
#  'From 1985 to 1995 there was a slow growing of percentage according to tha table (11% -16%), but after 1995 the percentage increased fast during next 10 years.',
#  'The presented data shows us the percentage of people aged 65 and over in three different countries (USA, Sweden and Japan) in the second half of the 20th century and up to 2040.',
#  'Overall, from the graph we can see that during all the period difference was falling and bottomed out at the end of the period in all countries, which were used in the research.',
#  'It is second popular reason for using facebook.',
#  'And in this month the max temprature is less than -20 degrees and the minimum temprature is lower of 10 degrees.',
#  'The distribution by gender is showed by the colomn.',
#  'The second pie chart shows us amount of goods transported by road between countries in Eastern Europe in 2008.',
#  'This chrats illustrate how changes in the use of Facebook from 2012 to 2013 an the main reasons for using it among men and women.',
#  'However, the percentage of female in services in Australia is much bigger than that in Indonesia.',
#  "Africa didn't show the what was happened in the world so Asia is.",
#  'Moreover, speaking specifically and precisely, the most popular courses for middle-age group were Sports and Health courses and Art courses for old-age.',
#  'The region of Africa shows the highest level of the data.',
#  'For example, the amount of grocery, transported by the road, is thrice as high, as transported by rail.',
#  'An overall trend is that the youngest age group is expected to decrease both in Yemen and Italy, while, in contrary, the oldest age group is going to increase.',
#  'In this way highest salary in japan.',
#  'Men that age from 16 to 54 and from 65 over 75 prefer doing sport activity and the percentage of man more than the number of women.',
#  'Women also prevail among people who use facebook to see funny posts and learning about helping others.',
#  'This can be result of peoples retirement.',
#  'This network has an equel 22% of users in age groups from 18 to 29 and from 65 and older.',
#  'On the first chart we can see that overall number of users slightly increased between 2012 and 2013.',
#  'For people between 16 and 24 and people from 75 the difference in time spent doing sport between males and females is almost three times, while for people from 55 to 74 this difference is not that dramatic (females between 55 and 64 spend even slightly more time doing sport that males: 52.7 for men and 55.4 for women).',
#  'According to table in 1990 the percentage of boys doing sport was higher than the girls (51% and 57% respectively).',
#  'As for developed countries, the investment in this kind of countries is much more higher than in developning ones.',
#  'The table and graph provide the information about proportion of children doing sport exercise between 1990 and 2005 and percentage of kids, who suffer from obesity in Canada during the period from 1985 to 2005.',
#  'The rate of unemployment decreased in Middle East and Latin America by 1,4% and 1% consequently.',
#  'All in all, man exrcised more often and longer than women, however the gap is smaller depending on the age.',
#  'Between the age of 45 and 54 they exercise 70,2 minutes on average.',
#  'It is also should be noted, that the graph of New Zealand salary inequity shows a confident decrease after the 1985.',
#  ...]

# %%
corrections
# Out:
# ["Sports and Health courses can be considered the 'oldest' because their visitors are mostly between 26-40 years old (62%) and older than 40 years old (23%) out of a total of 630 students.",
#  'To sum up, the young generation prefers communication via the Internet more often than elderly people.',
#  'Also, the percentage of people 40 years old and above on different courses is less than half.',
#  "It can be clearly seen from the graph that the trend of Japan and Sweden's older citizens is similar from 1940 to approximately 1992.",
#  'In second place are manufactured goods, with 25%.',
#  'In 1990, the gradual decline slowed down in the UK, USA, and New Zealand, while Germany even experienced a significant increase in the income difference.',
#  'In sum, Agriculture, Industry, and Services had 72, 23, and 105 workers, respectively.',
#  'The least active category, in terms of exercise time, is the age group over 75, with both genders spending no more than 30 minutes on training.',
#  'This feature applies to the United Kingdom and New Zealand.',
#  'As can be seen from the first chart, the total number of Facebook followers increased.',
#  'By contrast, in 1980, the USA indicator demonstrated the second largest percentage difference, but by 1995, it had fallen significantly to 20 and became the third largest, surpassed by the UK.',
#  'The chart below illustrates changes in Facebook usage from 2013 to 2013 and the main reasons for using it among males and females.',
#  'The first chart clearly shows that there are more visits abroad by UK residents than visits to the UK by overseas residents.',
#  'The peak of this situation was in 2005, when the percentage of boys with overweight became 25%.',
#  "The men's category was still higher overall, although it dropped slightly in the 55 to 64 age group.",
#  'The chart below provides information about changes in worldwide investment in renewable energy.',
#  "Another key point is the Bachelor's degree.",
#  'There was a sharp increase in mobile usage, which can be explained by the beginning of widespread smartphone use, but desktop usage did not decrease dramatically.',
#  'Although, like developed countries, they also experienced a downturn in 2013.',
#  'They help us to communicate and share our impressions.',
#  'The second chart shows the goods that were transported by road.',
#  'However, throughout the entire period, we cannot see a stable increase in invested money; it fluctuated slightly, sometimes increasing and sometimes decreasing.',
#  'From 1980 to 1995, Japan, the USA, the UK, Germany, and New Zealand saw a decline in the percentage difference in income between men and women.',
#  "Females were more willing to complete their education with either an undergraduate diploma or a bachelor's degree than males were.",
#  'Another notable fact is that Australia also reported the lowest numbers (1% and 3%, respectively) in the agriculture sector.',
#  'Comparing 2014 and 2015, we can see that the unemployment rate decreased in the Middle East and Latin America.',
#  'The same trend can be observed in the UK, where income fell gradually from 35% to 24% over 15 years.',
#  'Overall, it is clear that metal is primarily transported by rail, while food products are transported by road.',
#  'The bar charts below represent the changes in Facebook usage and common reasons for using it among men and women from 2012 to 2013.',
#  'It can be clearly seen from the graph that Facebook is the major player compared to other websites.',
#  'However, the graph highlights a considerable difference between travel abroad by UK residents and travel to the UK by overseas residents in the period from 1999.',
#  'Heavy products, such as metals and machinery, were rather transferred by road, while perishable products, including chemicals and food, were transported by truck.',
#  'The amount of time young men spend doing sports is almost twice as high as that of men in the next age group, which is 153,000 hours.',
#  'Making a prediction about the future, I would say that the investment rate in the world will continue to decline.',
#  'Overall, the main trends found are that men spend more time doing exercises than women do, and age has an indirect correlation with the time spent on leading an active lifestyle.',
#  'Overall, it is clear that the percentage difference in income between males and females has declined gradually in Japan, the USA, the UK, and New Zealand.',
#  'Overall, it can be seen that the smallest difference occurred in Germany and New Zealand, while in Japan the difference is significant.',
#  'To sum up, global development affects every continent on Earth and this is very good.',
#  'In terms of chemicals, it accounts for the average proportion and has almost the same percentage in both charts, with slight differences - 11% and 16% respectively.',
#  'The trend also never climbed suddenly.',
#  'Two countries showed less difference in earnings between men and women than the previously mentioned countries.',
#  'To sum it up, the graphs can be compared in one striking point.',
#  'The gender salary gap was already quite small in Germany and New Zealand, with neither exceeding 25%.',
#  'Women use social networks to share photos and video content, and for entertainment, such as watching funny pictures and learning about ways to help others, 8% to 15% more than males.',
#  'In 2000, Yemen had an almost equal number of children and adults, whereas Italy had 47.3% more adults than children.',
#  'The difference in the growth of overweight boys and girls is 4 percent.',
#  'It is clear that in Australia, more female workers are employed in the service sector, while in Indonesia, the percentage of women working in agriculture and services is fairly similar.',
#  'The given charts illustrate information about the two types of goods transportation (by rail and by road) between Eastern European countries in 2008.',
#  'These two pictures depict the average maximum and minimum temperature levels in two cities: Yakutsk, Russia, and Rio de Janeiro, Brazil.',
#  'Overall, the most popular sector of work in both countries, among all genders, is the service sector, with other economic sectors having fewer people.',
#  'To begin with, the percentage of male workers is higher than that of female workers in Indonesia and Australia, but in Australia, the services sector has more women than men.',
#  'On the contrary, in 2000, South Asia had a large number of uneducated children, but this number decreased significantly and reached a low of 4.8 million girls and 5.1 million boys.',
#  'However, the proportions of goods transported by road were not the same.',
#  'Women in the 25-34 and 35-44 age groups spent the same amount of time exercising, which equals 92.8 minutes, while men aged 25-34 tended to exercise more than those in the 35-44 age group.',
#  'And in Africa, the number of girls was higher than that of boys in 2012 and 2000.',
#  'Moreover, it is essential to notice that the agriculture sector in Australia, compared to the same sector in Indonesia, illustrates entirely different trends.',
#  'The table illustrates the proportion of men and women employed in three different sectors in Indonesia and Australia in 2010.',
#  'According to the chart, the worldwide unemployment rate was nearly 6% in 2014 and 2015.',
#  'As appears in part of the chart, in 1990, slightly more than half of the population had regular physical activity.',
#  'The level of decrease is most significant in the UK, at about 20.',
#  'Interestingly, women aged 55-64 spent around 3 minutes more on sports than men.',
#  'Chemicals are more frequently transported by road than by rail.',
#  'As can be seen from the chart, the highest number of children without education was in Africa in 2000, with just under 45 million, and the lowest was in the rest of the world, with under 25 million.',
#  'On the other hand, the level of investment in renewable energy worldwide increased from 2006 to 2009, from $100 billion to $168 billion, and then saw a significant surge from 2009 to 2011, peaking at $279 billion in 2011.',
#  'The number of desktop users decreased by 20%.',
#  'The second chart shows us the reasons why people use Facebook, again dividing users into males and females.',
#  'Firstly, the number of male workers is roughly twice that of female workers in Indonesia, whereas in Australia, the proportion of male to female workers in the industry is approximately three to one.',
#  'While in Australia, most females prefer the services sector, male workers are employed in both industrial and services sectors, with the agricultural sector being unpopular among both genders.',
#  'Finally, Sports and Health courses are more popular among middle-aged students, with 62% of all students being between 26 and 40 years old.',
#  "It is noticeable that men's qualifications are greater in number than those of women.",
#  'Units are measured in percentages.',
#  'The graph below provides us with information about changes in school assessment.',
#  'The overall structure changed significantly.',
#  'Significantly, only a small proportion of both genders worked in the agricultural sphere in Australia.',
#  'German was below the countries I mentioned but above New Zealand in 1980.',
#  'Both charts represent information about goods transported by various means: rail and road in Eastern Europe in 2008.',
#  'Initially, the male rate is more than two times higher than the female rate.',
#  'Comparing the data between 2000 and 2012, the 2012 indexes for Africa equal the 2000 indexes for South Asia.',
#  'However, since the 1990s, the number of people aged 65 and over has increased from 3% to 26% by 2040.',
#  'It is clear that the number of children without access to education is commonly decreasing.',
#  'But the smallest number of employers that can be seen in the sphere of technology is 800, as of 1998.',
#  'China became the largest fossil fuel consumer among the given countries, accounting for almost 90% of US consumption in 1970.',
#  'The main trend is that men engage in sport and exercise more intensely than women in almost every age category.',
#  'The represented countries, such as the USA, the UK, and New Zealand, showed a gradual reduction in this percentage difference over the whole period.',
#  'The USA is located near Japan.',
#  'The chart provides information on the number of boys and girls who engaged in regular exercise in 1990 and 2005.',
#  'From 2000 to 2005, the percentage of boys with weight problems predominated; in 2000, it was 21%, whereas the percentage of girls was 1% lower, and in 2005, the number of overweight boys was 3% higher.',
#  'Additionally, the line graph showing income differences in Germany fell to 10% in 1990 but then began to rise slowly to 13%.',
#  'Moreover, over a 5-year difference, the percentage of overweight girls increased by 2%, while the number of boys increased by only 1%.',
#  'From the start in 2006, with around 70 billion, to the end of the period in 2013, with around 130 billion.',
#  'Its rates were the highest in 2015, while those of other countries decreased gradually.',
#  'The chart below provides us with information on the transportation of goods in Eastern Europe in 2008.',
#  'Considering March 2012, it is notable that there is a difference between desktop and mobile use among approximately 110 million users.',
#  'In South Asia in 2000, there were 21.6 million girls and 11.1 million boys who lacked access to primary education.',
#  'The information that attracts the most attention is that almost all age groups have men with higher average time spent.',
#  'In South Asia and Africa, the level of access to primary education for girls in 2000 was higher than that of boys.',
#  'Furthermore, food products make up 30% of all road-transported goods, but for goods transported by rail, this figure is 11%.',
#  'What can be concluded from the above is that the difference in income between males and females has been decreasing since 1980.',
#  "If we analyze the women's chart, we can see that there is not a significant difference between the charts.",
#  'The second largest portion of rail goods transport is manufactured goods, which account for exactly a quarter of the total amount of goods.',
#  'In conclusion, although the number of men and women is decreasing, the male part of the population in England was more active than the female in 2012.',
#  'On average, one fourth of them visit these courses.',
#  'Lastly, the chart shows that women use Facebook for learning about how to help others 10% more than men.',
#  'In contrast to food products, chemicals and non-metallic minerals make up the majority of road transportation.',
#  'Finally, as can be seen in the first table, the number of male workers is higher than that of female workers by 7 people in the services sector.',
#  'Although over half of Facebook users considered photo and video sharing the main reason for social networking, the proportion in this category decreased from 54 percent in 2012 to 39 percent in 2013, which may be a consequence of increased app functionality.',
#  'It can be seen that at the beginning of the year, the temperature in Rio de Janeiro is very high and varies between 23 and 30 degrees Celsius.',
#  "Overall, the differences between the two countries' employment sectors are obvious and can be explained by a number of factors, including historical background, geographical position, and their place in the world's political arena.",
#  'In conclusion, these two tables clearly show that Australians prefer to work in the industry and service sectors rather than in agriculture, but in Indonesia, workers prefer the agriculture and service sectors.',
#  'Turning to the first table, the biggest percentage of male workers in Indonesia are interested in services, followed by agriculture, and then industry, respectively.',
#  'It can be seen from the chart that as British people mature, they become less willing to participate in sports.',
#  'Firstly, the percentage of energy derived from fossil fuels in France was 90 per cent in 1970.',
#  'I should say that females have a variety of main reasons for using Facebook.',
#  'In Yemen, it is around 40-50 per cent, whereas in Italy, it is a very small number.',
#  'Moreover, the highest total of words is 279, which occurred in 2011.',
#  'The bar chart illustrates the dependence of age groups on the use of three various social networks (Facebook, Instagram, and LinkedIn) in the USA.',
#  'It is evident that the income gap between men and women in all countries decreased after 1978.',
#  'The first chart provides information about visits abroad made by UK residents and trips to the UK conducted by foreign residents.',
#  'As we can see, in Australia, this sector illustrates almost minimal quantities, whereas in Indonesia, in contrast, agriculture is the second most common occupation.',
#  'It is remarkable that the least represented group in all three networks, namely people aged 65 or older, is equally present on LinkedIn.',
#  'However, there is a notable detail: while investments in 2012 decreased in both developed countries and overall, developing countries actually reached their highest level, and only then did their numbers start to decline.',
#  'On the other hand, India, which was initially at the bottom, became one of the leaders by the end of the period in question.',
#  'Although men use Facebook to learn about ways to help people less than women - 35% and 25% respectively, this difference is worth noting.',
#  'By contrast, only 39% of men use Facebook for sharing media content.',
#  'The largest parties are those involved in manufactured goods and metals.',
#  'Also, among five different types of qualifications, males made up the largest proportion, with involvement in various qualifications.',
#  'Although the agricultural employment sector is more widespread in Indonesia than in Australia, the latter shows higher employment in the industrial sector.',
#  'Interestingly, half of the surveyed women thought that the most important reason to use Facebook is to share photos and videos.',
#  'Between 1940 and 1980, the percentage of aged people in Sweden and the USA grew steadily: from 9% to 15% in the USA and from 7% to 14% in Sweden.',
#  'The vertical axis represents gender.',
#  'Only the European Union had a trend of rising rates.',
#  'The chart shows a dramatic decrease in sports activities among the two younger groups, for example, men aged 25-34 did almost half as much sport as those aged 16-24.',
#  'Next came a rapid and remarkable fall to the level of $214 billion.',
#  'Nevertheless, the indices of mobile Facebook remained significantly lower than those of desktop Facebook, reaching a peak of about 95 and 150 million users, respectively.',
#  'The tables show the employment of workers in Indonesia and Australia, broken down by gender.',
#  'This chart provides information about the income differences between the two genders in five nations over a 15-year period, from 1980 to 1995.',
#  'By far, the most popular job field for both men and women in Indonesia is services.',
#  'Chemicals account for 16 percent, non-metallic minerals account for 13 percent, and metals account for 11 percent.',
#  'The minimum temperature is approximately -40 degrees in two months: January and December.',
#  'The two presented table charts highlight the difference in labor force participation between men and women in the two neighboring countries, Australia and Indonesia, in 2010.',
#  'Surprisingly, the tables have turned, and in 2005 the percentage of overweight boys was 3 percent higher than that of girls.',
#  'Also worth noting is that the industry in both countries did not exceed 50% even when combined.',
#  'According to prisoners in the USA, white people accounted for 33 percent, which is 34 percent fewer than the number of non-white people.',
#  'The charts below show the main reasons for studying among students of different age groups and the amount of support they received from employers.',
#  'According to the graph, there will be a significant rise in the proportion of people aged 65 and over in Japan, from 10% in 2020 to 27% in 2040.',
#  'The second largest measure was in postgraduate diplomas.',
#  'The increase in the percentage of overweight girls and boys was not dramatically fast.',
#  'In Australia, female workers tend to work in services, where almost 9 out of 10 females are employed, rather than in agriculture, where only 1 in 100 females work.',
#  'The most popular rail transport industry was the metal industry; however, food production led road transportation in 2008.',
#  'In conclusion, the transportation of goods in Eastern Europe in 2008 was highly effective.',
#  'However, it should be noted that this age category deliberated in the last type of courses.',
#  'The least meaningful reason for using Facebook is to learn about ways to help others, for both men and women.',
#  'This is the only sector in which the ratio of people in Indonesia is higher.',
#  'Overall, it is clear that rail transportation was more suitable for heavier goods that did not require urgent delivery, as they were not time-sensitive.',
#  'The table shows the number of people who regularly engaged in sports in 1990 and 2005.',
#  'Additionally, manufactured goods increased from 25 percent to 28 percent.',
#  'The chart provides information about unemployment rates in different regions of the world in 2014 and 2015.',
#  'The graph shows the amount of energy gained from fossil fuels by five nations.',
#  'To sum up, the differences in post-school qualifications according to gender are significant enough, making it difficult to summarize the overall trend of the graph.',
#  'With respect to developing countries, there was an increase from 2006 to 2012, but a slight decrease was observed in the last year.',
#  'The pie charts show details of transportation for different produced goods by train and by motor in Eastern European countries.',
#  'Unfortunately, the London Underground is not the most popular because the Tokyo Underground has the largest number of visitors (1927).',
#  'In the Middle East and Latin America, this level is decreasing, but this change is not exceeding two percent.',
#  'The industrial sector is the smallest sector in Indonesia.',
#  'To conclude, as can be seen from the provided chart, the goods transported by railway are often metals, while those transported by road are food products.',
#  'The unemployment rate in the Middle East and Latin America has decreased, so the situation has changed in a positive way.',
#  'The line representing the decrease in such differences in Japan, a region with the most significant income difference between men and women, shows 40% in 1980, which is twice as high as the percentage shown in the same year in New Zealand.',
#  'Seeing funny posts is more popular among women than men, at 43% compared to 35%.',
#  'According to the information in the table, we can see a growth in the percentage of girls and boys who engage in regular physical activity.',
#  'Only in one age group, 55 to 64 years, do women engage in more sports than men; in all other groups, men are in the lead.',
#  'Moreover, the graph and table show that the number of boys who have problems with their height is greater, as is the number of boys who regularly exercise.',
#  'This graph shows us information about the Facebook company, including how and why its users utilize the platform.',
#  'Investments in developed countries are higher but less stable.',
#  'For both genders, exercise time has decreased nearly tenfold from the maximum to the minimum point.',
#  'The two presented line graphs illustrate temperature information for two cities, Yakutsk, Russia, and Rio de Janeiro, Brazil, over the course of a year.',
#  'The same situation applies to chemicals.',
#  'To sum up, there is a downward trend indicating that older people from both gender groups engaged in less exercise than younger people in 2012.',
#  'Nevertheless, both percentages increased every five years, fluctuating roughly at the same percentage.',
#  'The changes in the rest of the world were similar to those in Africa.',
#  'In Australia, 65% of males and 88% of females are represented, while in Indonesia, the percentages are 56% and 49%, respectively.',
#  'According to the figures, people of all ages spend a significant portion of their leisure time on sports activities.',
#  'Developed countries started investing in renewable energy in 2006, with a total of approximately $70 billion, while developing countries invested around $30 billion.',
#  'From 1995 to 1999, the number of minutes of local calls increased from 70 billion to 90 billion.',
#  '87% of young people spend their time on Facebook.',
#  'The graph shows that the level of overweight boys and girls is roughly the same.',
#  'Regarding food products, the opposite situation can be observed, as they are the most popular type of goods for car transport, accounting for 30% of the total volume, and one of the least popular products for rail transport.',
#  'There is also a significant percentage growth in the number of active boys and girls from 1990 to 2005.',
#  "However, Yemen has a large number of children, making up about half of the country's total population.",
#  'In 2012, UK colleges had 650 students studying science courses in total, with 15% being 40 years old or above, 30% between 26 and 40 years old, and 55% between 18 and 25 years old.',
#  'Both numbers are ten times higher than the results for people over 75.',
#  'The combined line graph and bar chart show the investments in renewable energy of developing and developed countries worldwide between 2006 and 2013 in billions of dollars.',
#  'In 2008, as shown on the graph, in Europe, chemicals were transported in equal amounts by roads and rails, at 16% and 11%, respectively.',
#  'The main trend was that the percentage difference in earnings decreased steadily in all the presented countries.',
#  'The graph shows the number of Facebook users in March 2012 and 2013 who preferred mobile or desktop versions.',
#  'However, there is a significant difference between these countries in the services sector - the number of female workers in Indonesia is 7% lower than the number of male workers, while the number of female workers in the Australian services sector is 24% higher than the number of male workers.',
#  'According to the global statistics, we can generally see a rise in finance investment from 2006 to 2010, with a modest pause in 2007-2009, followed by gradual growth from 2009 to 2011.',
#  'Although the graph showing the temperature in Rio does not have such sharp peaks, the line reaches its highest point in January, when the temperature is about 30°C, looking at the maximum line, and about 23°C at the minimum.',
#  'The graph shows that in 1980, the difference in outcomes in the former was approximately 35-40%, while in the latter, this feature was 15-20% lower.',
#  'From 55 to 64, this is the only period when women spent more minutes on exercise in 2012, but the difference in numbers is not as large as in the period from 16 to 24.',
#  'In March 2012, the number of people using the desktop version was approximately 150 million, and almost 140 million had downloaded the mobile app.',
#  'Having said that, the services sector had the majority percentage in both countries.',
#  'In the beginning, developed countries invested nearly 60 billion, but after that, it rose sharply to 151 billion from 2006 to 2010.',
#  'The given diagram represents how the percentage of the population aged over 65 years changed in the period from 1940 to 2040 in Japan, Sweden, and the USA.',
#  'The greatest change in percentage is only a few percent.',
#  'The same 15% of electricity is used for lighting, TV, radio, and vacuum cleaners, as well as food mixers and electronic tools.',
#  'The bar chart shows the average time men and women spent doing sports.',
#  'The given pie charts below illustrate information about the transportation of goods between countries in Eastern Europe in 2008.',
#  'The population of Yemen in 2000 was mostly comprised of children aged up to 14 years, who made up a little more than half of the population (50.1%), along with teenagers and middle-aged people.',
#  'Between 2008 and 2009, the amount of investment fluctuated, but after peaking in 2011, it decreased dramatically to a total of $214 billion invested by all countries in 2013.',
#  'The highest point in this country was reached in 1985, with a value of just above 40 percent.',
#  'On the other hand, Australia has a similarly large percentage of workers in the services sector - 65% for men and 88% for women.',
#  'Graphs represent several reasons for using Facebook, such as posting photos and videos, receiving updates, seeing funny posts, and learning about ways to help others.',
#  'The same tendency was observed in China - 4.8 billion US Dollars and 0.5 billion Dollars.',
#  '28% of these goods were transported by cars, and 25% were transmitted by trains.',
#  'By contrast, the number of employees in the agricultural sector is extremely low.',
#  'Overall, there are different patterns of transportation by rail and by road.',
#  'However, the proportion of boys and girls has not changed.',
#  'Pie charts represent the proportion of consumer demand shipped between Eastern European countries in 2008 by rail and road.',
#  'As we can see, in Italy, people aged 15-59 make up 61.6% of the population, while the minority are youngsters under the age of 14.',
#  'However, while the agriculture sector ranks second in employment statistics, it is the least popular place to work in Australia.',
#  'We can see that this graph is decreasing.',
#  'In 2014, European countries had a 7.5% unemployment rate.',
#  'The data is divided into 7 age groups and 2 genders.',
#  'In Italy, this age group comprised one-fourth of the population.',
#  "In the meantime, women's involvement in sports at the age of over 75 is just 10 minutes, which is nearly 10 minutes less than men's.",
#  'So, in the industrial sphere, there are almost twice as many men (15%) as women (8%).',
#  'There are two charts for Yemen and two charts for Italy, which give us information about the percentage of people under 14 years old, 15-59 years old, and people older than 60 years old.',
#  'In Indonesia, 29 men had a job in the agricultural area, 15 men worked in the industrial sector, and the majority of male workers had a job in services.',
#  'The least popular reason for using Facebook is learning about ways to help others.',
#  'It can be deduced from the graph that sharing photos and videos was the main reason for using Facebook among men and women, but the percentage of women was considerably higher - 54% compared to 39% of men.',
#  'To sum up, the main difference in the transportation of goods between rail and road lies in the type of goods, with food requiring mostly short-term transportation and metals and machinery being difficult to transport in large amounts by road.',
#  'The percentage of women doing it is 54%, while that of men is 39%.',
#  'Important decreases among countries occurred in the following year, 2012.',
#  "As can be observed, physical activity gradually decreases with the growth of the respondent's age.",
#  'Overall, from 1980 to 1995, the difference in earnings between the USA and Japan was declining.',
#  'To sum up, although children are able to engage in physical activity more than before, there is a trend of increasing overweight among boys and girls throughout the period.',
#  'These types of transportation play different roles in the transportation of goods between countries.',
#  'The number of desktop users decreased, but only by 15 million users, which is only ten percent of all users.',
#  'Agriculture is a far less common choice for men in Australia.',
#  'At the age of 25-34 and 35-44, female respondents spent the same number of minutes doing sports, 92.8 minutes.',
#  'In each chart, we can see that there are two major sections, which are transported in a particular way.',
#  'Countries in 1940 included only 5-10% of elderly people (65 years and over); however, researchers suppose that the proportion of this demographic in the population of countries will be about 20-30% by 2040.',
#  'It is noticeable that in 2012, users more often preferred desktops, while in 2013, mobile devices became more preferable.',
#  'In 2011, developed countries reached an absolute peak in investment in renewable energy, with a value almost twice that of the investment value of developing countries in the same year.',
#  'The largest number of goods transported by road is food products (30%).',
#  'Due to this fact, we can see a slight fall in 2009 in total investments from $171 billion to $168 billion.',
#  'In the case of women, it can be seen that only 1% of female workers have jobs in the agricultural sector, while most women are employed in service jobs.',
#  'However, from 2011 to 2013, a rapid downward trend can be observed.',
#  'Only manufactured goods and chemicals increased their share by 3% and 5%, respectively, from chart 1 to chart 2.',
#  'The percentage of overweight boys was the highest throughout the period, rising from 57% in 1990 to 87% in 2005.',
#  'There were 74 and 26 percent respectively.',
#  'Another popular reason that users cited was receiving updates.',
#  "Secondly, there is another tendency - most women preferred to take the undergraduate diploma or the bachelor's degree: 70 percent versus 37 percent, and 53 percent versus 48 percent.",
#  'Overall, in 1990 there was a clear correlation between the number of children of a particular sex who engaged in physical activity and those who were overweight.',
#  "We can see this on the graph, where the scale shows that 'for interest' grows rapidly from 25% in the 30-39 age group to 70% in the category over 49.",
#  'These changes created balance, and as a result, the worldwide unemployment rate remained unchanged in 2015.',
#  'Overall, it is clear that the oldest underground railway system is in London, with the highest total route length of 394 kilometers.',
#  'In 1995, two countries reached a record 10 percent difference.',
#  'Talking about rail, it is especially popular for transporting metals (35%) and manufactured goods (25%).',
#  'The first chart shows the number of users who used two versions of the site, desktop and mobile, in March 2012 and March 2013.',
#  'Then, men aged 55 to 64 did fewer exercises than men aged 65 to 74 by about 8 minutes.',
#  'However, in the 55-65 age group, people did it slightly less than in the 65-74 age group, with a difference of about 10 minutes.',
#  'Three regions had similar values during this period, but one region had a slight change in its percentage numbers.',
#  'Regarding other countries, we see an oscillation in the percentage difference in earnings between men and women.',
#  'The second place on the chart is taken by postgraduate diplomas, which have 30 percent fewer than skilled vocational diplomas.',
#  "There were two moments - in 2009 and in 2012 - when developed countries reduced their investments, but developing countries' investments continued to grow.",
#  'By the end of 2012, the indices had fallen by 10 million.',
#  'In 2012, desktops were more popular among women, but by 2013, they had become less popular compared to mobile devices, showing a significant decrease from 140 million to 60 million users.',
#  'On the other hand, the minimum proportion of countries was in 1940, which was about 5-10%.',
#  'The younger people are, the more time they spend doing exercises.',
#  "Although, let's take a look at the second chart, where we can see that the overall number of Facebook users are women, except when receiving updates, in which the percentage of usage is the same, 39%.",
#  "The dynamic of men's sports interest slowly fell among the 55-64 age group.",
#  'Overall, developed countries have invested the most throughout the period.',
#  'According to the chart, the number of girls and boys without the opportunity to go to primary school is equal in every region.',
#  'Meanwhile, the use of the desktop version is consistent throughout the period.',
#  'More than half of male workers and approximately the majority of female workers have their place of occupation in such a field.',
#  'These networks give people easier ways to have fun and share information with each other, which are the main reasons for all genders to use Facebook.',
#  'There is also a line representing the world total; all this information illustrates the tendencies of investment in different countries between 2006 and 2013.',
#  'Furthermore, the situation in the industrial arena of these two countries is pretty similar: male workers dominate when compared to female workers.',
#  'The graph represents the investment in renewable energy over 8 years and shows the difference in investment between developed and developing countries.',
#  'The first tendency noticeable on the chart is that the quantity of males with skilled vocational diplomas is 9 times higher than that of females with such diplomas.',
#  'In contrast, 45% of students in their 40s and above are among those studying art courses.',
#  "The population of the USA is expected to increase from 16% to 23% by 2040, while Sweden's population is projected to grow from 18% to 25% by 2040.",
#  'For instance, more than half of the students in science courses belong to the 18-25 age group, whereas the majority of arts course attendees, 45%, are people older than 45.',
#  'The two pie charts illustrate the proportion of various types of goods transported in Eastern Europe by rail and by road over a one-year period.',
#  'This pie chart illustrates the percentage of products conveyed by rail and by road through Eastern European countries in 2008.',
#  'The tendency is similar to the global total, but in the case of developed countries, investment was approximately three times larger than in developing countries, at around $75 billion and $25 billion respectively in 2006.',
#  'To sum up, there are significant differences between goods transported by rail and road.',
#  'However, it must be noted that the situation in the USA changed more dramatically, with the percentage halving in size, while the percentage for the UK reduced by only 12%.',
#  'The graph provides information about investments in renewable energy from 2006 to 2013.',
#  'Here, we can see differences between Africa, South Asia, and the rest of the world from 2000 to 2012.',
#  '87% of adults aged 18 to 29 use Facebook, as well as 73% of adults aged 30 to 49, 63% of those aged 50 to 64, and 56% of users over 65.',
#  'For example, the average young girl in the 16-24 age group spends 114.1 minutes on sports, which is 2.5 minutes less than the time spent by a male in the same group.',
#  'In contrast, the USA showed the highest results during the period between 1940 and 1990, demonstrating stable growth from approximately 9% in 1940 to about 14% in 1990.',
#  'Overall, it can be seen that the number of men and women using Facebook has experienced a downward trend on both types of devices, although mobile devices showed less of a surge.',
#  'The difference in income in the USA and UK was quite similar, at 30% and 33% at the beginning and 20% and 23% at the end, respectively.',
#  'There is a significant difference between men and women in the 16-24 age category.',
#  'We can see that the main reason for using Facebook among both women and men is sharing photos or videos, while the lowest point is learning about ways to help others.',
#  'But in 50 years, children will have grown up, and they will have become old men, and the number of young people will have decreased.',
#  'In Indonesia, the industry is in second place, whereas in Australia it is in third place.',
#  'In 1990, Germany reached a global minimum of 10 percent, while Japan reached the highest value at 35 percent.',
#  'By 2009, it had slightly decreased to approximately $100 billion.',
#  'These pie charts illustrate the ratios of various goods transported by rail and road between Eastern European countries in 2008.',
#  'However, the gap in time between both genders decreases with age.',
#  'The percentage of manufactured goods is very similar in both types of transportation, making up approximately 26 percent.',
#  'In contrast, more than half of women consider sharing photos and videos the main reason for using this network, while only 39 percent of men support this idea.',
#  'Generally, the reasons for using Facebook are common, but a different number of males and females choose different reasons.',
#  'In Germany, the difference in income between different genders has plummeted since the early 1980s.',
#  "Additionally, the proportion of female students adopting a bachelor's degree was also higher than that of the opposite gender, at approximately 55 percent and 45 percent respectively.",
#  'After a period of stagnation between 2008 and 2009, it rose dramatically and reached a peak of $279 billion in 2011.',
#  'According to the projections for 2050, the percentage is expected to decline to 46.2%, whereas the percentage of old people is expected to increase.',
#  'The following chart illustrates the proportion of men and women who engaged in sports and exercise in England in 2012, divided into age groups.',
#  'However, the unemployment rate reached its peak in North Africa in both 2014 and 2015, with 12.5%.',
#  'Also, women prefer to learn about ways to help others, but only 25% of men do so.',
#  'Overall, judging by the graph for the total worldwide change in energy investment, one can observe that there was continuous growth up until 2008, when the amount invested hit a plateau, which was followed by a rapid increase in 2010.',
#  'These three countries are the USA, Sweden, and Japan.',
#  'Only 11% of women worked in the industrial area, while men accounted for 32% in this sector.',
#  'The smallest number of passengers is in Kyoto and Los Angeles, with 45 and 50 million visitors per year, respectively.',
#  'If we look at the chart, we can see that in 2012, very few boys and girls were going to school, compared to 2000.',
#  'I hear that renewable energy technologies are not as effective as traditional energy technologies and have a negative impact on the surroundings.',
#  'Speaking of similarities between these two tables, there are more men than women in the agriculture sector in both countries.',
#  'The table and chart below illustrate the percentage of girls and boys who had weight problems in Canada from 1985 to 2005, and the percentage of teenagers who engaged in regular physical activity in 1990 and 2005.',
#  'A similar tendency can be observed in Latin America as in the Middle East.',
#  'Unemployment decreased from 11 to 9.6.',
#  'However, by the end of the decade, the difference in income between men and women dropped severely by 15 percentage points in all countries compared to 1980.',
#  'The percentage difference in the USA was about 40 percent in 1980, while it fell to 20 percent by the end of the period.',
#  'Regarding the second graph, we can see a diagram of the reasons for using Facebook.',
#  'If we look at the percentage of boys with the same problem, this statistic increases slightly between 1985 and 1990, but from 1990 to 2005, it increases dramatically by 4 percent every 5 years.',
#  'As can be seen from the diagram, the number of people who prefer to use desktops at the beginning of the period reaches approximately 150 million, while the number of mobile users exceeds 40 million.',
#  'Among males working in agriculture, there are only 29 percent in Indonesia, while in Australia, it is only 8 percent.',
#  'In Germany, the sum of money dedicated to print editions remained stable at 6 billion US dollars in both 2014 and 2018.',
#  'However, by 1995, Germany had returned to 4th place with a slight increase, marking the end of its decline.',
#  'To conduct our own analysis, we will examine all the data presented separately.',
#  'The number of people visiting libraries to study has fallen dramatically from 1990 to 2000.',
#  'A 75-year-old man spent only around 29 minutes on sports, while a woman spent significantly more, over 10 minutes more.',
#  'The quantity of people there accounts for almost 50 percent of all workers in these three sectors.',
#  'The gap in the amount of time spent on sports is decreasing until the 55-64 age group.',
#  'According to the first chart, it is possible to say that metals were the most popular category to transport in 2008 in Eastern Europe.',
#  'It should be noted that the lowest percentage difference in earnings (10%) was recorded in Germany in 1980.',
#  'By 1995, the amount of overweight girls and boys had leveled out and increased two-fold by 2005, whereas in 1985 it was less than 15 percent.',
#  'Secondly, students in the 26-40 age category make up the majority of those taking Sports and Health courses (62 percent), while the same category has the lowest percentage for Arts courses (25 percent).',
#  'Moreover, there is a significant difference in the transportation of goods by rail and road in Eastern European countries: 35% by rail and only 11% by road.',
#  'On the contrary, the rate in the EU had an increase of 0.4%. ',
#  'Overall, according to the 2018 forecast, the eBook market is expected to become more popular: in the USA, it is predicted to grow to $8.5 billion in annual profit, while in Germany and China it will rise to $0.5 billion and $1.5 billion and $1 billion, respectively.',
#  'Overall, statistics on British people engaging in sports show that men are generally more active in sports than women, and the average time spent on sports and exercise decreases as people get older.',
#  'Overall, the majority of people used to access Facebook via desktops rather than mobile phones.',
#  "Let's discuss the similarities.",
#  'The charts illustrate the number of goods transported by rail and road in Eastern Europe in 2008.',
#  'The difference between the highest and lowest temperatures did not exceed 15 degrees.',
#  'It is also measured as a percentage.',
#  'Generally speaking, men prefer to have an undergraduate diploma.',
#  'The vertical one shows that most users use the desktop version.',
#  'In 1980, all the presented countries started from their peak in percentage difference, except for Japan.',
#  'Besides, the most significant change in the unemployment rate over the years has been illustrated by the Middle East.',
#  'To sum up, as a result of rapid growth in Japan by the end of the period, Japan was the leader among all countries in the proportion of the population aged 65 and over.',
#  'While the table shows the percentage of the same children who did regular physical activity in 1990 and 2005.',
#  'To sum up, according to the graph, it is clear that there was an upward trend in changes in investment in renewable energy until 2011.',
#  'There is a tendency for investment in this field to have reached a peak in 2011, with just one exception (in developing countries, the peak was in 2012).',
#  'The bar chart gives information about the average time spent on sports activities by the British in 2012.',
#  'This chart and table illustrate the number of boys and girls who were overweight in Canada from 1985 to 2005, and the number of young people who exercised between 1990 and 2005.',
#  'The bar chart under analysis describes the changes in the number of overweight children over a period of twenty years, from 1985 to 2005, while the table under consideration demonstrates the changes in the number of children engaging in sports on a regular basis over a period of fifteen years, from 1970 to 2005.',
#  'It can be seen that the majority of people in both countries work in the service sector.',
#  'Even though girls became much more active in 2005 compared to 1990, boys still outperform girls in regular physical activity.',
#  'While the proportion of men interested in this is low, at 25 per cent.',
#  'The chart showing the percentage of girls and boys who engaged in regular physical activity in 1990 and 2005 actually shows that they did more physical activity over time.',
#  'While Japan had the highest proportion of income between both genders over the 15-year period, the group consisting of Germany and New Zealand, on the contrary, had the lowest percentage of earnings.',
#  'People under 26 years old who like rules tend to go to university for their career.',
#  'The difference in the UK at the beginning was about 20% and by 1982 it had exceeded that of the USA.',
#  'Speaking of men, more than a third answered that the main reason for using Facebook is also the ability to share this specific type of content.',
#  'However, in other countries, there are some exceptions.',
#  'However, in 1985 the percentage of girls was higher, but in 2005, 25% of boys and 22% of girls had weight problems.',
#  'Also, the difference between the maximum and minimum average temperatures remained almost the same throughout the whole period, while in Yakutsk the difference decreased by half in January and December compared to July.',
#  'However, South Asia in 2000 was an exception.',
#  'The illustrations demonstrate the proportions of goods transported by rail and by road between Eastern European countries in 2008.',
#  'All information is divided into two parts by gender.',
#  'Also, there is a table below that gives us an insight into the percentage of girls and boys who engaged in some kind of physical activity regularly between 1990 and 2005.',
#  'Then it decreases considerably until the age of 55, when there is another drop to 52.7, which is half as much as in the previous cluster.',
#  'Secondly, in Latin America, the level of unemployment also plummeted (from 6.8 to 5.8).',
#  'Overall, every mode of transportation specializes in different goods.',
#  'At that time, more people preferred to use the mobile version.',
#  'In this report, I am going to explain the information given in the two tables above.',
#  'Overall, we can see that the amount and type of goods delivered between countries vary to a certain extent depending on the kind of transportation.',
# ...
#  'It can be seen that some countries have the same level of unemployment, such as North Africa and South Asia.',
#  'Moreover, it is quite important to mention that the number of students in every course is approximately the same, so it can be said that there is no correlation between the number of students and the main topic of the course.',
#  'The two graphs provide information on how people used Facebook between 2013 and 2014 and why different genders used this social network.',
#  'Overall, the tendency is that the older the person, the less time they spend on physical exercises, because the average sport time declines gently with age.',
#  'Females are not interested in this sphere, which is why the number of males is relatively high, making up to 90% of all participants.',
#  'Also, the time spent on sports by women aged 25-44 remains at the same level.',
#  'With regards to the remaining methods, the percentage of both sexes who engaged in regular physical activity and were overweight showed a slight increase of about 2-3% among girls and boys, and it was 16% for both sexes in 1995.',
#  'In this essay, I will summarize the selected information about them and attempt to provide a comparative analysis.',
#  'Reading newspapers accounted for only 5% in 2000, whereas it was 15% in 1990.',
#  "It is interesting to note that when the iPhone's popularity fell by up to 60%, Samsung's became the biggest this year.",
#  'If we conduct a brief analysis of these investments, we can see that the lowest number was around $75 billion in 2006, and the peak was in 2011, reaching $175 billion.',
#  'Moreover, the smallest transported part is also different: machinery is the category of goods most transported by road, and non-metallic minerals are the goods most transported by rail.',
#  'Before this, in both 1985 and 1990, the rate for girls was higher than for boys, accounting for 12% (in 1985) and 14% (in 1990), while boys constituted 11% (in 1985) and 12% (in 1990).',
#  'It is also easy to notice that agriculture is much less popular in Australia, where only 3% of men and 1% of women work in this sector, compared to 29% and 49% in Indonesia.',
#  'Old people, 60+ years, make up a significant portion in Italy, both in 2000 and 2050.',
#  "First, we can see that the world's total spending gradually increased until 2011 (from $100 billion in 2006 to $279 billion in 2011), with a barely noticeable decrease in 2008 and 2009, where it almost plateaued at the $170 billion mark.",
#  'In contrast to the younger group, students 40 years old and above are less interested in sports, making up approximately a quarter.',
#  'In comparison to these two regions, the rest of the world has fewer people who do not have access to primary education.',
#  'By the way, only a quarter and almost a third of all students are attending art and science courses, respectively, within the 26-40 age group.',
#  'Food products and chemical products have equal shares, which are 11%.',
#  'It is clear that the population level has risen over this period in all countries.',
#  'As can be seen from the chart, the average time spent on sports activities in England in 2012, by age and gender, is illustrated.',
#  'The points reached a peak in 2005, at 22%, which is only 3% less than the percentage of boys.',
#  'In 2012, approximately 30.6 million girls still did not have access to primary schools.',
#  'The chart shows a comparison of two types of transportation between parts of Eastern Europe in 2008.',
#  'There was a noticeable increase in the difference in salary between males and females in Japan from 1975 to 1985.',
#  'Then, after a small drop, investment rebounded and reached its peak in 2011.',
#  'National and international fixed-line subscriptions grew steadily from slightly less than 40 billion in 1995 to 70 billion by the end of the period.',
#  'So far, using Facebook on the desktop has become more popular than on mobile.',
#  'Overall, according to the graph, it can be seen that the difference in income between men and women has become smaller over the period.',
#  'Chemicals, Food, and the second one accounted for 11 percent.',
#  'There were just over 11 million boys without primary education in that region in 2000, but by 2012 this number had decreased by around 50% from the initial level.',
#  'Speaking about differences according to gender, men tend to engage in sports and exercises more often than women.',
#  'In stark contrast to this, the percentage of boys improved from 11% in 1985 to 12% in 1990.',
#  'The least prominent sphere of employment was agriculture in Australia.',
#  'It can be concluded from the graph that seeing funny posts is more interesting for women than for men.',
#  'The situations in the USA and UK looked similar.',
#  'In 2000, the most problematic regions were Africa and South Asia, where approximately seventy-five million children could not attend school.',
#  'Overall, it is clear that the percentage of manufactured goods is almost the same and is one of the largest components of both charts.',
#  'As for predictions for Yemen in 2050, they will be rather optimistic, because the central age group (15-59) will comprise about 57.3% of the total population.',
#  "The next age group, people aged 15-59 years, accounts for 46.3% of Yemen's population.",
#  'The chart below shows that the number of children without access to primary education is decreasing worldwide.',
#  'Only in the age range of 52 to 55 do women spend more time on physical activities.',
#  'It is immediately obvious that there are significant differences between the two charts.',
#  "As for the Bachelor's degree, the percentage of males and females was roughly the same in 1999.",
#  'The least popular sector in Australia is the agricultural sector, while more than a quarter of men in Indonesia work in this sector; according to this table, it is easy to mention that the male and female population of the country works in every sector in practically the same proportions.',
#  'Facebook and Instagram are both more popular among younger people and less popular among older ones.',
#  'As can be seen, about 90% of men have obtained a skilled vocational diploma, while just over 10% of women have done so.',
#  'And the second graph shows changes in the main reasons for using Facebook among women and men.',
#  'Overall, even at first glance, we can spot the remarkable progress of Japan, which used to be the worst of these three countries in 2040 and managed to become the first by 2040.',
#  'The figure compares how people engaged in sports activities in the UK in 2012.',
#  'Firstly, we can see that the younger you are, the more time you spend on physical health, compared to those over 75 years old.',
#  'It is interesting to note that nearly equal parts of the manufactured goods were transported by both means of transport, 25% by rail and 25% by road.',
#  'Moreover, as a rule, men spend more time on sports than women.',
#  'As we can see, each age group preferred each category of courses to a different extent, depending on their age.',
#  'Overall, it shows that more users choose the mobile version of Facebook compared to the previous year, but still fewer than the website; also, the chart demonstrates that women are the majority on Facebook due to a larger percentage of usage.',
#  'What about the reasons, many people use Facebook for sharing photos and videos.',
#  'In addition, there is a minority of women working in the agricultural sphere.',
#  'In other age groups, the decline was more or less steady.',
#  "In just one year, Facebook's members started using mobile phones 40% more often than in 2012.",
#  'Secondly, the smallest percentage was in machinery, with 2% transported by road and zero percent by rail.',
#  'As is evident, employment division is currently affected by various aspects, but some categories, such as gender and different regions, influence working clusters.',
#  'The most radical fluctuation among all is the fall in the Middle East unemployment rate, from 11% to 9.6% over a year.',
#  'In general, at the beginning of the last decade of the 20th century, public libraries were visited by over one-third of a billion citizens.',
#  'Using this web source on desktops declined by March 2013 from 150 million users to 135 million, whereas this number rose sharply from 55 million users to 95 million with the use of mobile phones.',
#  "On the graph, we see that a large number of boys and girls in Africa wish they didn't have to get an education.",
#  'Secondly, developing countries invested more and more money in renewable resources from 2006 to 2012, but in 2013 the mentioned parameter declined by about $10 billion and reached $90 billion.',
#  'In detail, the number of people aged 15-59 was higher in Italy, at 61.6%, whereas in Yemen this figure was 46.3% in 2000.',
#  'Otherwise, the industry sector is more popular in Australia.',
#  'However, between some years, there are small decreases in the population.',
#  'However, the percentage of men who use Facebook is higher, at 54 compared to 39 for women.',
#  'Here, the amount of time men spend exercising is more than twice that of women: 282.1 minutes vs. 114.1.',
#  "In the table, after 2000, the major level of obesity increased, but the boys' population had a higher percentage of overweight individuals than their counterparts.",
#  'It can be clearly seen that the USA is a prominent leader in book sales.',
#  'Next to metals, manufactured goods are produced, which account for one quarter of the total amount.',
#  'The difference in income between men and women reached its peak in Japan approximately in 1985.',
#  'Then, a parallel can be seen between the growth of age and the rise of indifference to social media among users.',
#  'Finally, despite different changes in populations that can occur according to predictions for 2050, it is right to say that the whole population will become older, with fewer teenagers and more elderly people.',
#  'From the first chart, we can see that the decrease in Facebook usage on desktop computers is relatively low compared to the increase on cellphones, with a change of about one fourth.',
#  'At first glance, it is absolutely clear that there was a significant fluctuation during this time.',
#  'It is easy to see that the industry field is not popular among workers in Indonesia.',
#  'We can see that children and teenagers (people aged 0 to 14) in both countries are losing their proportion of the population.',
#  'It consists of 65 men and 88 women.',
#  'Nevertheless, it increased rapidly until 2013 and then similarly dropped during the same period.',
#  'The difference between the highest and lowest points is extremely large, with investment in renewable energy rising by $179 billion from 2006 to 2011.',
#  'It is interesting to note that the amount of manufactured goods transported by road is nearly similar to the amount transported by rail, with the first being only 3% higher.',
#  'There is a significant difference in the number of elderly people (60+ years) between the two countries: 3.6% in Yemen and 24.1% in Italy.',
#  'By looking at the three charts, one may notice a strong correlation between the type of courses and the age of the majority of attendees.',
#  'In comparison, Indonesia has 29% and 43% of workers in the agricultural sector.',
#  'The least popular reason for using Facebook is learning about ways to help others.',
#  'We can conclude that agriculture is more developed in Indonesia than in Australia.',
#  'While the highest percentage that girls reached in 2005 is approximately 22%; generally speaking, the percentage of children of both genders has significantly increased over fifteen years.',
#  'The number of them was 54%.',
#  'To sum up, we can see that the graph illustrates a prediction for 2040.',
#  'Most women in Australia work in the service sector, totaling 88 percent; as for men, this value is not so great but still more than half.',
#  'The figure of money that will be reached by selling printed and e-books in this country is around 16 billion US dollars.',
#  'The tables illustrate the percentage of employees divided by sex in two countries: Indonesia and Australia.',
#  'At the same time, the number of people using the mobile version of Facebook had significantly risen from less than 60 million users in March 2012 to almost 100 million in March 2013.',
#  "The number of boys with obesity also reached a peak in 2005, but was lower than the girls' rate and accounted for 22 percent.",
#  'Overall, it can be seen that the largest market for all kinds of books is located in the USA.',
#  'From 1985 to 1995, there was a slow increase in the percentage according to the table (11%-16%), but after 1995, the percentage increased rapidly over the next 10 years.',
#  'The presented data show the percentage of people aged 65 and over in three different countries (the USA, Sweden, and Japan) in the second half of the 20th century and up to 2040.',
#  'Overall, from the graph, we can see that during the entire period, the difference was decreasing and reached its lowest point at the end of the period in all countries included in the research.',
#  'It is the second most popular reason for using Facebook.',
#  'And in this month, the maximum temperature is less than -20 degrees, and the minimum temperature is 10 degrees lower.',
#  'The distribution by gender is shown by the column.',
#  'The second pie chart shows the amount of goods transported by road between countries in Eastern Europe in 2008.',
#  'These charts illustrate how the use of Facebook changed from 2012 to 2013 and the main reasons for using it among men and women.',
#  'However, the percentage of females in services in Australia is significantly higher than that in Indonesia.',
#  'Africa did not reflect what was happening in the world, unlike Asia.',
#  'Moreover, speaking specifically, the most popular courses for the middle-aged group were sports and health courses, and art courses for the elderly.',
#  'The African region shows the highest level of data.',
#  'For example, the amount of groceries transported by road is three times as high as that transported by rail.',
#  'An overall trend is that the youngest age group is expected to decrease in both Yemen and Italy, while, in contrast, the oldest age group is expected to increase.',
#  'In this way, Japan has the highest salary.',
#  'Men aged 16 to 54 and over 65 prefer doing sports activities, and the percentage of men is higher than that of women.',
#  'Women also predominate among people who use Facebook to view funny posts and learn about helping others.',
#  "This can be a result of people's retirement.",
#  'This network has an equal 22% of users in the age groups from 18 to 29 and from 65 and older.',
#  'On the first chart, we can see that the overall number of users slightly increased between 2012 and 2013.',
#  'For people between 16 and 24 and those aged 75 and older, the difference in time spent doing sports between males and females is almost three times, while for people from 55 to 74, this difference is not as dramatic (females between 55 and 64 spend even slightly more time doing sports than males: 52.7 for men and 55.4 for women).',
#  'According to the table, in 1990, the percentage of boys doing sports was higher than that of girls (57% and 51%, respectively).',
#  'As for developed countries, investment in these countries is much higher than in developing ones.',
#  'The table and graph provide information about the proportion of children doing sports exercises between 1990 and 2005 and the percentage of kids who suffer from obesity in Canada during the period from 1985 to 2005.',
#  'The rate of unemployment decreased in the Middle East and Latin America by 1.4% and 1%, respectively.',
#  'All in all, men exercise more often and longer than women; however, the gap is smaller depending on age.',
#  'Between the ages of 45 and 54, they exercise for 70.2 minutes on average.',
#  "It should also be noted that the graph of New Zealand's salary inequity shows a significant decrease after 1985.",
#  ...]

# %%
dataset_dict = {
    'train': {
        'source': sources_fw,
        'target': corrections_fw
    },
    'validation': {
        'source': ds['validation']['source'],
        'target': corrections
    }
}

# %%
from datasets import Dataset, DatasetDict

# %%
hf_dataset = DatasetDict({
    'train': Dataset.from_dict(dataset_dict['train']),
    'validation': Dataset.from_dict(dataset_dict['validation'])
})

# %%
ds['validation']['source']

# %%
print(f"Dataset contains {len(hf_dataset['train'])} examples")
print(f"Dataset contains {len(hf_dataset['validation'])} examples")
print("\nFirst 3 examples:")
for i in range(min(3, len(hf_dataset['train']))):
    print(f"Source: {hf_dataset['train'][i]['source']}")
    print(f"Target: {hf_dataset['train'][i]['target']}")
print("\nFirst 3 examples:")
for i in range(min(3, len(hf_dataset['train']))):
    print(f"Source: {hf_dataset['validation'][i]['source']}")
    print(f"Target: {hf_dataset['validation'][i]['target']}")
# Out:
# Dataset contains 28497 examples
# Dataset contains 3558 examples
#
# First 3 examples:
# Source: First of all, we can see increasing tendency of overweighting during the hole period.
#
# Target: First of all, we can see an increasing tendency of overweight during the whole period.
#
# Source: Food products were mostly transportaded by the road.
#
# Target: Food products were mostly transported by road.
#
# Source: For the same period of life, man dramastically decreases spent time from 282,1 minutes to 60,5 minutes.
#
# Target: For the same period of life, men dramatically decrease the time spent from 282.1 minutes to 60.5 minutes.
#
#
# First 3 examples:
# Source: Sports and Health cources can be named as the "oldest" because their visitors mostly 26-40 years old- 62% and older than 40 years old - 23% from total amount of people (630 students).
# Target: Sports and Health courses can be considered the 'oldest' because their visitors are mostly between 26-40 years old (62%) and older than 40 years old (23%) out of a total of 630 students.
# Source: To sum up, young generation prefer communication via the Internet more often than elderly people.
# Target: To sum up, the young generation prefers communication via the Internet more often than elderly people.
# Source: Also, the percentage of 40 years old and above people on different courses is less then half.
# Target: Also, the percentage of people 40 years old and above on different courses is less than half.

# %%
username = "Zlovoblachko"
dataset_name = "Llama-REALEC-GEC-train_val"

# %%
hf_dataset.push_to_hub(f"{username}/{dataset_name}")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/Zlovoblachko/Llama-REALEC-GEC-train_val/commit/9839b681894165a151a9dd7599a96c1f85dbe047', commit_message='Upload dataset', commit_description='', oid='9839b681894165a151a9dd7599a96c1f85dbe047', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Zlovoblachko/Llama-REALEC-GEC-train_val', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Zlovoblachko/Llama-REALEC-GEC-train_val'), pr_revision=None, pr_num=None)
